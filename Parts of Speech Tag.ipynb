# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import pickle

import keras
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences, to_categorical
from keras.models import Model,Sequential
from keras.layers import Dense,SimpleRNN,Embedding,LSTM,GRU,Bidirectional,TimeDistributed,InputLayer
from sklearn.model_selection import train_test_split

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import brown,treebank

# %% [markdown]
# ## Creating Dataset

# %%
treebank.tagged_sents(tagset="universal")[0]
# Out:
# [('Pierre', 'NOUN'),
#  ('Vinken', 'NOUN'),
#  (',', '.'),
#  ('61', 'NUM'),
#  ('years', 'NOUN'),
#  ('old', 'ADJ'),
#  (',', '.'),
#  ('will', 'VERB'),
#  ('join', 'VERB'),
#  ('the', 'DET'),
#  ('board', 'NOUN'),
#  ('as', 'ADP'),
#  ('a', 'DET'),
#  ('nonexecutive', 'ADJ'),
#  ('director', 'NOUN'),
#  ('Nov.', 'NOUN'),
#  ('29', 'NUM'),
#  ('.', '.')]

# %%
d1 = treebank.tagged_sents(tagset="universal")

# %%
brown.tagged_sents(tagset="universal")[0]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP'),
#  ("Atlanta's", 'NOUN'),
#  ('recent', 'ADJ'),
#  ('primary', 'NOUN'),
#  ('election', 'NOUN'),
#  ('produced', 'VERB'),
#  ('``', '.'),
#  ('no', 'DET'),
#  ('evidence', 'NOUN'),
#  ("''", '.'),
#  ('that', 'ADP'),
#  ('any', 'DET'),
#  ('irregularities', 'NOUN'),
#  ('took', 'VERB'),
#  ('place', 'NOUN'),
#  ('.', '.')]

# %%
d2 = brown.tagged_sents(tagset="universal")

# %%
dataset = d1+d2

# %%
dataset
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], ...]

# %%
len(dataset)
# Out:
# 61254

# %%
x = []
y = []
for l in dataset:
    x1 = []
    y1 = []
    for t in l:
        x1.append(t[0])
        y1.append(t[1])
        
    x.append(x1)
    y.append(y1)

# %%
len(x)
# Out:
# 61254

# %%
len(y)
# Out:
# 61254

# %%
x #Input Variable
# Out:
# [['Pierre',
#   'Vinken',
#   ',',
#   '61',
#   'years',
#   'old',
#   ',',
#   'will',
#   'join',
#   'the',
#   'board',
#   'as',
#   'a',
#   'nonexecutive',
#   'director',
#   'Nov.',
#   '29',
#   '.'],
#  ['Mr.',
#   'Vinken',
#   'is',
#   'chairman',
#   'of',
#   'Elsevier',
#   'N.V.',
#   ',',
#   'the',
#   'Dutch',
#   'publishing',
#   'group',
#   '.'],
#  ['Rudolph',
#   'Agnew',
#   ',',
#   '55',
#   'years',
#   'old',
#   'and',
#   'former',
#   'chairman',
#   'of',
#   'Consolidated',
#   'Gold',
#   'Fields',
#   'PLC',
#   ',',
#   'was',
#   'named',
#   '*-1',
#   'a',
#   'nonexecutive',
#   'director',
#   'of',
#   'this',
#   'British',
#   'industrial',
#   'conglomerate',
#   '.'],
#  ['A',
#   'form',
#   'of',
#   'asbestos',
#   'once',
#   'used',
#   '*',
#   '*',
#   'to',
#   'make',
#   'Kent',
#   'cigarette',
#   'filters',
#   'has',
#   'caused',
#   'a',
#   'high',
#   'percentage',
#   'of',
#   'cancer',
#   'deaths',
#   'among',
#   'a',
#   'group',
#   'of',
#   'workers',
#   'exposed',
#   '*',
#   'to',
#   'it',
#   'more',
#   'than',
#   '30',
#   'years',
#   'ago',
#   ',',
#   'researchers',
#   'reported',
#   '0',
#   '*T*-1',
#   '.'],
#  ['The',
#   'asbestos',
#   'fiber',
#   ',',
#   'crocidolite',
#   ',',
#   'is',
#   'unusually',
#   'resilient',
#   'once',
#   'it',
#   'enters',
#   'the',
#   'lungs',
#   ',',
#   'with',
#   'even',
#   'brief',
#   'exposures',
#   'to',
#   'it',
#   'causing',
#   'symptoms',
#   'that',
#   '*T*-1',
#   'show',
#   'up',
#   'decades',
#   'later',
#   ',',
#   'researchers',
#   'said',
#   '0',
#   '*T*-2',
#   '.'],
#  ['Lorillard',
#   'Inc.',
#   ',',
#   'the',
#   'unit',
#   'of',
#   'New',
#   'York-based',
#   'Loews',
#   'Corp.',
#   'that',
#   '*T*-2',
#   'makes',
#   'Kent',
#   'cigarettes',
#   ',',
#   'stopped',
#   'using',
#   'crocidolite',
#   'in',
#   'its',
#   'Micronite',
#   'cigarette',
#   'filters',
#   'in',
#   '1956',
#   '.'],
#  ['Although',
#   'preliminary',
#   'findings',
#   'were',
#   'reported',
#   '*-2',
#   'more',
#   'than',
#   'a',
#   'year',
#   'ago',
#   ',',
#   'the',
#   'latest',
#   'results',
#   'appear',
#   'in',
#   'today',
#   "'s",
#   'New',
#   'England',
#   'Journal',
#   'of',
#   'Medicine',
#   ',',
#   'a',
#   'forum',
#   'likely',
#   '*',
#   'to',
#   'bring',
#   'new',
#   'attention',
#   'to',
#   'the',
#   'problem',
#   '.'],
#  ['A',
#   'Lorillard',
#   'spokewoman',
#   'said',
#   ',',
#   '``',
#   'This',
#   'is',
#   'an',
#   'old',
#   'story',
#   '.'],
#  ['We',
#   "'re",
#   'talking',
#   'about',
#   'years',
#   'ago',
#   'before',
#   'anyone',
#   'heard',
#   'of',
#   'asbestos',
#   'having',
#   'any',
#   'questionable',
#   'properties',
#   '.'],
#  ['There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '.', "''"],
#  ['Neither',
#   'Lorillard',
#   'nor',
#   'the',
#   'researchers',
#   'who',
#   '*T*-3',
#   'studied',
#   'the',
#   'workers',
#   'were',
#   'aware',
#   'of',
#   'any',
#   'research',
#   'on',
#   'smokers',
#   'of',
#   'the',
#   'Kent',
#   'cigarettes',
#   '.'],
#  ['``',
#   'We',
#   'have',
#   'no',
#   'useful',
#   'information',
#   'on',
#   'whether',
#   'users',
#   'are',
#   'at',
#   'risk',
#   ',',
#   "''",
#   'said',
#   '*T*-1',
#   'James',
#   'A.',
#   'Talcott',
#   'of',
#   'Boston',
#   "'s",
#   'Dana-Farber',
#   'Cancer',
#   'Institute',
#   '.'],
#  ['Dr.',
#   'Talcott',
#   'led',
#   'a',
#   'team',
#   'of',
#   'researchers',
#   'from',
#   'the',
#   'National',
#   'Cancer',
#   'Institute',
#   'and',
#   'the',
#   'medical',
#   'schools',
#   'of',
#   'Harvard',
#   'University',
#   'and',
#   'Boston',
#   'University',
#   '.'],
#  ['The',
#   'Lorillard',
#   'spokeswoman',
#   'said',
#   '0',
#   'asbestos',
#   'was',
#   'used',
#   '*-1',
#   'in',
#   '``',
#   'very',
#   'modest',
#   'amounts',
#   "''",
#   'in',
#   '*',
#   'making',
#   'paper',
#   'for',
#   'the',
#   'filters',
#   'in',
#   'the',
#   'early',
#   '1950s',
#   'and',
#   'replaced',
#   '*-1',
#   'with',
#   'a',
#   'different',
#   'type',
#   'of',
#   'filter',
#   'in',
#   '1956',
#   '.'],
#  ['From',
#   '1953',
#   'to',
#   '1955',
#   ',',
#   '9.8',
#   'billion',
#   'Kent',
#   'cigarettes',
#   'with',
#   'the',
#   'filters',
#   'were',
#   'sold',
#   '*-3',
#   ',',
#   'the',
#   'company',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['Among',
#   '33',
#   'men',
#   'who',
#   '*T*-4',
#   'worked',
#   'closely',
#   'with',
#   'the',
#   'substance',
#   ',',
#   '28',
#   '*ICH*-1',
#   'have',
#   'died',
#   '--',
#   'more',
#   'than',
#   'three',
#   'times',
#   'the',
#   'expected',
#   'number',
#   '.'],
#  ['Four',
#   'of',
#   'the',
#   'five',
#   'surviving',
#   'workers',
#   'have',
#   'asbestos-related',
#   'diseases',
#   ',',
#   'including',
#   'three',
#   'with',
#   'recently',
#   'diagnosed',
#   'cancer',
#   '.'],
#  ['The',
#   'total',
#   'of',
#   '18',
#   'deaths',
#   'from',
#   'malignant',
#   'mesothelioma',
#   ',',
#   'lung',
#   'cancer',
#   'and',
#   'asbestosis',
#   'was',
#   'far',
#   'higher',
#   'than',
#   '*',
#   'expected',
#   '*?*',
#   ',',
#   'the',
#   'researchers',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['``',
#   'The',
#   'morbidity',
#   'rate',
#   'is',
#   'a',
#   'striking',
#   'finding',
#   'among',
#   'those',
#   'of',
#   'us',
#   'who',
#   '*T*-5',
#   'study',
#   'asbestos-related',
#   'diseases',
#   ',',
#   "''",
#   'said',
#   '*T*-1',
#   'Dr.',
#   'Talcott',
#   '.'],
#  ['The',
#   'percentage',
#   'of',
#   'lung',
#   'cancer',
#   'deaths',
#   'among',
#   'the',
#   'workers',
#   'at',
#   'the',
#   'West',
#   'Groton',
#   ',',
#   'Mass.',
#   ',',
#   'paper',
#   'factory',
#   'appears',
#   '*-1',
#   'to',
#   'be',
#   'the',
#   'highest',
#   'for',
#   'any',
#   'asbestos',
#   'workers',
#   'studied',
#   '*',
#   'in',
#   'Western',
#   'industrialized',
#   'countries',
#   ',',
#   'he',
#   'said',
#   '0',
#   '*T*-2',
#   '.'],
#  ['The',
#   'plant',
#   ',',
#   'which',
#   '*T*-1',
#   'is',
#   'owned',
#   '*-4',
#   'by',
#   'Hollingsworth',
#   '&',
#   'Vose',
#   'Co.',
#   ',',
#   'was',
#   'under',
#   'contract',
#   '*ICH*-2',
#   'with',
#   'Lorillard',
#   '*',
#   'to',
#   'make',
#   'the',
#   'cigarette',
#   'filters',
#   '.'],
#  ['The',
#   'finding',
#   'probably',
#   'will',
#   'support',
#   'those',
#   'who',
#   '*T*-6',
#   'argue',
#   'that',
#   'the',
#   'U.S.',
#   'should',
#   'regulate',
#   'the',
#   'class',
#   'of',
#   'asbestos',
#   'including',
#   'crocidolite',
#   'more',
#   'stringently',
#   'than',
#   'the',
#   'common',
#   'kind',
#   'of',
#   'asbestos',
#   ',',
#   'chrysotile',
#   ',',
#   'found',
#   '*',
#   'in',
#   'most',
#   'schools',
#   'and',
#   'other',
#   'buildings',
#   ',',
#   'Dr.',
#   'Talcott',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['The',
#   'U.S.',
#   'is',
#   'one',
#   'of',
#   'the',
#   'few',
#   'industrialized',
#   'nations',
#   'that',
#   '*T*-7',
#   'does',
#   "n't",
#   'have',
#   'a',
#   'higher',
#   'standard',
#   'of',
#   'regulation',
#   'for',
#   'the',
#   'smooth',
#   ',',
#   'needle-like',
#   'fibers',
#   'such',
#   'as',
#   'crocidolite',
#   'that',
#   '*T*-1',
#   'are',
#   'classified',
#   '*-5',
#   'as',
#   'amphobiles',
#   ',',
#   'according',
#   'to',
#   'Brooke',
#   'T.',
#   'Mossman',
#   ',',
#   'a',
#   'professor',
#   'of',
#   'pathlogy',
#   'at',
#   'the',
#   'University',
#   'of',
#   'Vermont',
#   'College',
#   'of',
#   'Medicine',
#   '.'],
#  ['More',
#   'common',
#   'chrysotile',
#   'fibers',
#   'are',
#   'curly',
#   'and',
#   'are',
#   'more',
#   'easily',
#   'rejected',
#   '*-1',
#   'by',
#   'the',
#   'body',
#   ',',
#   'Dr.',
#   'Mossman',
#   'explained',
#   '0',
#   '*T*-2',
#   '.'],
#  ['In',
#   'July',
#   ',',
#   'the',
#   'Environmental',
#   'Protection',
#   'Agency',
#   'imposed',
#   'a',
#   'gradual',
#   'ban',
#   'on',
#   'virtually',
#   'all',
#   'uses',
#   'of',
#   'asbestos',
#   '.'],
#  ['By',
#   '1997',
#   ',',
#   'almost',
#   'all',
#   'remaining',
#   'uses',
#   'of',
#   'cancer-causing',
#   'asbestos',
#   'will',
#   'be',
#   'outlawed',
#   '*-6',
#   '.'],
#  ['About',
#   '160',
#   'workers',
#   'at',
#   'a',
#   'factory',
#   'that',
#   '*T*-8',
#   'made',
#   'paper',
#   'for',
#   'the',
#   'Kent',
#   'filters',
#   'were',
#   'exposed',
#   '*-7',
#   'to',
#   'asbestos',
#   'in',
#   'the',
#   '1950s',
#   '.'],
#  ['Areas',
#   'of',
#   'the',
#   'factory',
#   '*ICH*-2',
#   'were',
#   'particularly',
#   'dusty',
#   'where',
#   'the',
#   'crocidolite',
#   'was',
#   'used',
#   '*-8',
#   '*T*-1',
#   '.'],
#  ['Workers',
#   'dumped',
#   'large',
#   'burlap',
#   'sacks',
#   'of',
#   'the',
#   'imported',
#   'material',
#   'into',
#   'a',
#   'huge',
#   'bin',
#   ',',
#   'poured',
#   'in',
#   'cotton',
#   'and',
#   'acetate',
#   'fibers',
#   'and',
#   'mechanically',
#   'mixed',
#   'the',
#   'dry',
#   'fibers',
#   'in',
#   'a',
#   'process',
#   'used',
#   '*',
#   '*',
#   'to',
#   'make',
#   'filters',
#   '.'],
#  ['Workers',
#   'described',
#   '``',
#   'clouds',
#   'of',
#   'blue',
#   'dust',
#   "''",
#   'that',
#   '*T*-1',
#   'hung',
#   'over',
#   'parts',
#   'of',
#   'the',
#   'factory',
#   ',',
#   'even',
#   'though',
#   'exhaust',
#   'fans',
#   'ventilated',
#   'the',
#   'area',
#   '.'],
#  ['``',
#   'There',
#   "'s",
#   'no',
#   'question',
#   'that',
#   'some',
#   'of',
#   'those',
#   'workers',
#   'and',
#   'managers',
#   'contracted',
#   'asbestos-related',
#   'diseases',
#   ',',
#   "''",
#   'said',
#   '*T*-1',
#   'Darrell',
#   'Phillips',
#   ',',
#   'vice',
#   'president',
#   'of',
#   'human',
#   'resources',
#   'for',
#   'Hollingsworth',
#   '&',
#   'Vose',
#   '.'],
#  ['``',
#   'But',
#   'you',
#   'have',
#   '*-1',
#   'to',
#   'recognize',
#   'that',
#   'these',
#   'events',
#   'took',
#   'place',
#   '35',
#   'years',
#   'ago',
#   '.'],
#  ['It', 'has', 'no', 'bearing', 'on', 'our', 'work', 'force', 'today', '.'],
#  ['Yields',
#   'on',
#   'money-market',
#   'mutual',
#   'funds',
#   'continued',
#   '*-1',
#   'to',
#   'slide',
#   ',',
#   'amid',
#   'signs',
#   'that',
#   'portfolio',
#   'managers',
#   'expect',
#   'further',
#   'declines',
#   'in',
#   'interest',
#   'rates',
#   '.'],
#  ['The',
#   'average',
#   'seven-day',
#   'compound',
#   'yield',
#   'of',
#   'the',
#   '400',
#   'taxable',
#   'funds',
#   'tracked',
#   '*',
#   'by',
#   'IBC',
#   "'s",
#   'Money',
#   'Fund',
#   'Report',
#   'eased',
#   'a',
#   'fraction',
#   'of',
#   'a',
#   'percentage',
#   'point',
#   'to',
#   '8.45',
#   '%',
#   'from',
#   '8.47',
#   '%',
#   'for',
#   'the',
#   'week',
#   'ended',
#   'Tuesday',
#   '.'],
#  ['Compound',
#   'yields',
#   'assume',
#   'reinvestment',
#   'of',
#   'dividends',
#   'and',
#   'that',
#   'the',
#   'current',
#   'yield',
#   'continues',
#   'for',
#   'a',
#   'year',
#   '.'],
#  ['Average',
#   'maturity',
#   'of',
#   'the',
#   'funds',
#   "'",
#   'investments',
#   'lengthened',
#   'by',
#   'a',
#   'day',
#   'to',
#   '41',
#   'days',
#   ',',
#   'the',
#   'longest',
#   'since',
#   'early',
#   'August',
#   ',',
#   'according',
#   'to',
#   'Donoghue',
#   "'s",
#   '.'],
#  ['Longer',
#   'maturities',
#   'are',
#   'thought',
#   '*-1',
#   'to',
#   'indicate',
#   'declining',
#   'interest',
#   'rates',
#   'because',
#   'they',
#   'permit',
#   'portfolio',
#   'managers',
#   'to',
#   'retain',
#   'relatively',
#   'higher',
#   'rates',
#   'for',
#   'a',
#   'longer',
#   'period',
#   '.'],
#  ['Shorter',
#   'maturities',
#   'are',
#   'considered',
#   '*-9',
#   'a',
#   'sign',
#   'of',
#   'rising',
#   'rates',
#   'because',
#   'portfolio',
#   'managers',
#   'can',
#   'capture',
#   'higher',
#   'rates',
#   'sooner',
#   '.'],
#  ['The',
#   'average',
#   'maturity',
#   'for',
#   'funds',
#   'open',
#   'only',
#   'to',
#   'institutions',
#   ',',
#   'considered',
#   'by',
#   'some',
#   '*',
#   'to',
#   'be',
#   'a',
#   'stronger',
#   'indicator',
#   'because',
#   'those',
#   'managers',
#   'watch',
#   'the',
#   'market',
#   'closely',
#   ',',
#   'reached',
#   'a',
#   'high',
#   'point',
#   'for',
#   'the',
#   'year',
#   '--',
#   '33',
#   'days',
#   '.'],
#  ['Nevertheless',
#   ',',
#   'said',
#   '*T*-1',
#   'Brenda',
#   'Malizia',
#   'Negus',
#   ',',
#   'editor',
#   'of',
#   'Money',
#   'Fund',
#   'Report',
#   ',',
#   'yields',
#   '``',
#   'may',
#   'blip',
#   'up',
#   'again',
#   'before',
#   'they',
#   'blip',
#   'down',
#   "''",
#   'because',
#   'of',
#   'recent',
#   'rises',
#   'in',
#   'short-term',
#   'interest',
#   'rates',
#   '.'],
#  ['The',
#   'yield',
#   'on',
#   'six-month',
#   'Treasury',
#   'bills',
#   'sold',
#   '*',
#   'at',
#   'Monday',
#   "'s",
#   'auction',
#   ',',
#   'for',
#   'example',
#   ',',
#   'rose',
#   'to',
#   '8.04',
#   '%',
#   'from',
#   '7.90',
#   '%',
#   '.'],
#  ['Despite',
#   'recent',
#   'declines',
#   'in',
#   'yields',
#   ',',
#   'investors',
#   'continue',
#   '*-1',
#   'to',
#   'pour',
#   'cash',
#   'into',
#   'money',
#   'funds',
#   '.'],
#  ['Assets',
#   'of',
#   'the',
#   '400',
#   'taxable',
#   'funds',
#   'grew',
#   'by',
#   '$',
#   '1.5',
#   'billion',
#   '*U*',
#   'during',
#   'the',
#   'latest',
#   'week',
#   ',',
#   'to',
#   '$',
#   '352.7',
#   'billion',
#   '*U*',
#   '.'],
#  ['Typically',
#   ',',
#   'money-fund',
#   'yields',
#   'beat',
#   'comparable',
#   'short-term',
#   'investments',
#   'because',
#   'portfolio',
#   'managers',
#   'can',
#   'vary',
#   'maturities',
#   'and',
#   'go',
#   'after',
#   'the',
#   'highest',
#   'rates',
#   '.'],
#  ['The',
#   'top',
#   'money',
#   'funds',
#   'are',
#   'currently',
#   'yielding',
#   'well',
#   'over',
#   '9',
#   '%',
#   '.'],
#  ['Dreyfus',
#   'World-Wide',
#   'Dollar',
#   ',',
#   'the',
#   'top-yielding',
#   'fund',
#   ',',
#   'had',
#   'a',
#   'seven-day',
#   'compound',
#   'yield',
#   'of',
#   '9.37',
#   '%',
#   'during',
#   'the',
#   'latest',
#   'week',
#   ',',
#   'down',
#   'from',
#   '9.45',
#   '%',
#   'a',
#   'week',
#   'earlier',
#   '.'],
#  ['It',
#   'invests',
#   'heavily',
#   'in',
#   'dollar-denominated',
#   'securities',
#   'overseas',
#   'and',
#   'is',
#   'currently',
#   'waiving',
#   'management',
#   'fees',
#   ',',
#   'which',
#   '*T*-9',
#   'boosts',
#   'its',
#   'yield',
#   '.'],
#  ['The',
#   'average',
#   'seven-day',
#   'simple',
#   'yield',
#   'of',
#   'the',
#   '400',
#   'funds',
#   'was',
#   '8.12',
#   '%',
#   ',',
#   'down',
#   'from',
#   '8.14',
#   '%',
#   '.'],
#  ['The',
#   '30-day',
#   'simple',
#   'yield',
#   'fell',
#   'to',
#   'an',
#   'average',
#   '8.19',
#   '%',
#   'from',
#   '8.22',
#   '%',
#   ';',
#   'the',
#   '30-day',
#   'compound',
#   'yield',
#   'slid',
#   'to',
#   'an',
#   'average',
#   '8.53',
#   '%',
#   'from',
#   '8.56',
#   '%',
#   '.'],
#  ['J.P.',
#   'Bolduc',
#   ',',
#   'vice',
#   'chairman',
#   'of',
#   'W.R.',
#   'Grace',
#   '&',
#   'Co.',
#   ',',
#   'which',
#   '*T*-10',
#   'holds',
#   'a',
#   '83.4',
#   '%',
#   'interest',
#   'in',
#   'this',
#   'energy-services',
#   'company',
#   ',',
#   'was',
#   'elected',
#   '*-10',
#   'a',
#   'director',
#   '.'],
#  ['He',
#   'succeeds',
#   'Terrence',
#   'D.',
#   'Daniels',
#   ',',
#   'formerly',
#   'a',
#   'W.R.',
#   'Grace',
#   'vice',
#   'chairman',
#   ',',
#   'who',
#   '*T*-11',
#   'resigned',
#   '.'],
#  ['W.R.',
#   'Grace',
#   'holds',
#   'three',
#   'of',
#   'Grace',
#   'Energy',
#   "'s",
#   'seven',
#   'board',
#   'seats',
#   '.'],
#  ['Pacific',
#   'First',
#   'Financial',
#   'Corp.',
#   'said',
#   '0',
#   'shareholders',
#   'approved',
#   'its',
#   'acquisition',
#   'by',
#   'Royal',
#   'Trustco',
#   'Ltd.',
#   'of',
#   'Toronto',
#   'for',
#   '$',
#   '27',
#   '*U*',
#   'a',
#   'share',
#   ',',
#   'or',
#   '$',
#   '212',
#   'million',
#   '*U*',
#   '.'],
#  ['The',
#   'thrift',
#   'holding',
#   'company',
#   'said',
#   '0',
#   'it',
#   'expects',
#   '*-1',
#   'to',
#   'obtain',
#   'regulatory',
#   'approval',
#   'and',
#   'complete',
#   'the',
#   'transaction',
#   'by',
#   'year-end',
#   '.'],
#  ['McDermott',
#   'International',
#   'Inc.',
#   'said',
#   '0',
#   'its',
#   'Babcock',
#   '&',
#   'Wilcox',
#   'unit',
#   'completed',
#   'the',
#   'sale',
#   'of',
#   'its',
#   'Bailey',
#   'Controls',
#   'Operations',
#   'to',
#   'Finmeccanica',
#   'S.p',
#   '.',
#   'A.',
#   'for',
#   '$',
#   '295',
#   'million',
#   '*U*',
#   '.'],
#  ['Finmeccanica',
#   'is',
#   'an',
#   'Italian',
#   'state-owned',
#   'holding',
#   'company',
#   'with',
#   'interests',
#   'in',
#   'the',
#   'mechanical',
#   'engineering',
#   'industry',
#   '.'],
#  ['Bailey',
#   'Controls',
#   ',',
#   'based',
#   '*',
#   'in',
#   'Wickliffe',
#   ',',
#   'Ohio',
#   ',',
#   'makes',
#   'computerized',
#   'industrial',
#   'controls',
#   'systems',
#   '.'],
#  ['It',
#   'employs',
#   '2,700',
#   'people',
#   'and',
#   'has',
#   'annual',
#   'revenue',
#   'of',
#   'about',
#   '$',
#   '370',
#   'million',
#   '*U*',
#   '.'],
#  ['The',
#   'federal',
#   'government',
#   'suspended',
#   'sales',
#   'of',
#   'U.S.',
#   'savings',
#   'bonds',
#   'because',
#   'Congress',
#   'has',
#   "n't",
#   'lifted',
#   'the',
#   'ceiling',
#   'on',
#   'government',
#   'debt',
#   '.'],
#  ['Until',
#   'Congress',
#   'acts',
#   ',',
#   'the',
#   'government',
#   'has',
#   "n't",
#   'any',
#   'authority',
#   '*',
#   'to',
#   'issue',
#   'new',
#   'debt',
#   'obligations',
#   'of',
#   'any',
#   'kind',
#   ',',
#   'the',
#   'Treasury',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['The',
#   'government',
#   "'s",
#   'borrowing',
#   'authority',
#   'dropped',
#   'at',
#   'midnight',
#   'Tuesday',
#   'to',
#   '$',
#   '2.80',
#   'trillion',
#   '*U*',
#   'from',
#   '$',
#   '2.87',
#   'trillion',
#   '*U*',
#   '.'],
#  ['Legislation',
#   '0',
#   '*T*-1',
#   'to',
#   'lift',
#   'the',
#   'debt',
#   'ceiling',
#   'is',
#   'ensnarled',
#   '*-11',
#   'in',
#   'the',
#   'fight',
#   'over',
#   '*',
#   'cutting',
#   'capital-gains',
#   'taxes',
#   '.'],
#  ['The',
#   'House',
#   'has',
#   'voted',
#   '*-1',
#   'to',
#   'raise',
#   'the',
#   'ceiling',
#   'to',
#   '$',
#   '3.1',
#   'trillion',
#   '*U*',
#   ',',
#   'but',
#   'the',
#   'Senate',
#   'is',
#   "n't",
#   'expected',
#   '*-2',
#   'to',
#   'act',
#   'until',
#   'next',
#   'week',
#   'at',
#   'the',
#   'earliest',
#   '.'],
#  ['The',
#   'Treasury',
#   'said',
#   '0',
#   'the',
#   'U.S.',
#   'will',
#   'default',
#   'on',
#   'Nov.',
#   '9',
#   'if',
#   'Congress',
#   'does',
#   "n't",
#   'act',
#   'by',
#   'then',
#   '.'],
#  ['Clark',
#   'J.',
#   'Vitulli',
#   'was',
#   'named',
#   '*-12',
#   'senior',
#   'vice',
#   'president',
#   '*RNR*-1',
#   'and',
#   'general',
#   'manager',
#   '*RNR*-1',
#   'of',
#   'this',
#   'U.S.',
#   'sales',
#   'and',
#   'marketing',
#   'arm',
#   'of',
#   'Japanese',
#   'auto',
#   'maker',
#   'Mazda',
#   'Motor',
#   'Corp',
#   '.'],
#  ['In',
#   'the',
#   'new',
#   'position',
#   'he',
#   'will',
#   'oversee',
#   'Mazda',
#   "'s",
#   'U.S.',
#   'sales',
#   ',',
#   'service',
#   ',',
#   'parts',
#   'and',
#   'marketing',
#   'operations',
#   '.'],
#  ['Previously',
#   ',',
#   'Mr.',
#   'Vitulli',
#   ',',
#   '43',
#   'years',
#   'old',
#   ',',
#   'was',
#   'general',
#   'marketing',
#   'manager',
#   'of',
#   'Chrysler',
#   'Corp.',
#   "'s",
#   'Chrysler',
#   'division',
#   '.'],
#  ['He',
#   'had',
#   'been',
#   'a',
#   'sales',
#   'and',
#   'marketing',
#   'executive',
#   'with',
#   'Chrysler',
#   'for',
#   '20',
#   'years',
#   '.'],
#  ['When',
#   'it',
#   "'s",
#   'time',
#   'for',
#   'their',
#   'biannual',
#   'powwow',
#   '*T*-1',
#   ',',
#   'the',
#   'nation',
#   "'s",
#   'manufacturing',
#   'titans',
#   'typically',
#   'jet',
#   'off',
#   'to',
#   'the',
#   'sunny',
#   'confines',
#   'of',
#   'resort',
#   'towns',
#   'like',
#   'Boca',
#   'Raton',
#   'and',
#   'Hot',
#   'Springs',
#   '.'],
#  ['Not', 'this', 'year', '.'],
#  ['The',
#   'National',
#   'Association',
#   'of',
#   'Manufacturers',
#   'settled',
#   'on',
#   'the',
#   'Hoosier',
#   'capital',
#   'of',
#   'Indianapolis',
#   'for',
#   'its',
#   'fall',
#   'board',
#   'meeting',
#   '.'],
#  ['And',
#   'the',
#   'city',
#   'decided',
#   '*-1',
#   'to',
#   'treat',
#   'its',
#   'guests',
#   'more',
#   'like',
#   'royalty',
#   'or',
#   'rock',
#   'stars',
#   'than',
#   'factory',
#   'owners',
#   '.'],
#  ['The',
#   'idea',
#   ',',
#   'of',
#   'course',
#   ':',
#   '*',
#   'to',
#   'prove',
#   'to',
#   '125',
#   'corporate',
#   'decision',
#   'makers',
#   'that',
#   'the',
#   'buckle',
#   'on',
#   'the',
#   'Rust',
#   'Belt',
#   'is',
#   "n't",
#   'so',
#   'rusty',
#   'after',
#   'all',
#   ',',
#   'that',
#   'it',
#   "'s",
#   'a',
#   'good',
#   'place',
#   '0',
#   'for',
#   'a',
#   'company',
#   'to',
#   'expand',
#   '*T*-1',
#   '.'],
#  ['On',
#   'the',
#   'receiving',
#   'end',
#   'of',
#   'the',
#   'message',
#   'were',
#   '*T*-1',
#   'officials',
#   'from',
#   'giants',
#   'like',
#   'Du',
#   'Pont',
#   'and',
#   'Maytag',
#   ',',
#   'along',
#   'with',
#   'lesser',
#   'knowns',
#   'like',
#   'Trojan',
#   'Steel',
#   'and',
#   'the',
#   'Valley',
#   'Queen',
#   'Cheese',
#   'Factory',
#   '.'],
#  ['For',
#   'starters',
#   ',',
#   'the',
#   'executives',
#   'joined',
#   'Mayor',
#   'William',
#   'H.',
#   'Hudnut',
#   'III',
#   'for',
#   'an',
#   'evening',
#   'of',
#   'the',
#   'Indianapolis',
#   'Symphony',
#   'Orchestra',
#   'and',
#   'a',
#   'guest',
#   'pianist-comedian',
#   'Victor',
#   'Borge',
#   '.'],
#  ['Champagne', 'and', 'dessert', 'followed', '.'],
#  ['The',
#   'next',
#   'morning',
#   ',',
#   'with',
#   'a',
#   'police',
#   'escort',
#   ',',
#   'busloads',
#   'of',
#   'executives',
#   'and',
#   'their',
#   'wives',
#   'raced',
#   'to',
#   'the',
#   'Indianapolis',
#   'Motor',
#   'Speedway',
#   ',',
#   '*-1',
#   'unimpeded',
#   'by',
#   'traffic',
#   'or',
#   'red',
#   'lights',
#   '.'],
#  ['The',
#   'governor',
#   'could',
#   "n't",
#   'make',
#   'it',
#   ',',
#   'so',
#   'the',
#   'lieutenant',
#   'governor',
#   'welcomed',
#   'the',
#   'special',
#   'guests',
#   '.'],
#  ['A',
#   'buffet',
#   'breakfast',
#   'was',
#   'held',
#   '*-1',
#   'in',
#   'the',
#   'museum',
#   ',',
#   'where',
#   'food',
#   'and',
#   'drinks',
#   'are',
#   'banned',
#   '*-2',
#   'to',
#   'everyday',
#   'visitors',
#   '*T*-3',
#   '.'],
#  ['Then',
#   ',',
#   'in',
#   'the',
#   'guests',
#   "'",
#   'honor',
#   ',',
#   'the',
#   'speedway',
#   'hauled',
#   'out',
#   'four',
#   'drivers',
#   ',',
#   'crews',
#   'and',
#   'even',
#   'the',
#   'official',
#   'Indianapolis',
#   '500',
#   'announcer',
#   'for',
#   'a',
#   '10-lap',
#   'exhibition',
#   'race',
#   '.'],
#  ['After',
#   'the',
#   'race',
#   ',',
#   'Fortune',
#   '500',
#   'executives',
#   'drooled',
#   'like',
#   'schoolboys',
#   'over',
#   'the',
#   'cars',
#   'and',
#   'drivers',
#   '.'],
#  ['*-1',
#   'No',
#   'dummies',
#   ',',
#   'the',
#   'drivers',
#   'pointed',
#   'out',
#   '0',
#   'they',
#   'still',
#   'had',
#   'space',
#   'on',
#   'their',
#   'machines',
#   'for',
#   'another',
#   'sponsor',
#   "'s",
#   'name',
#   'or',
#   'two',
#   '.'],
#  ['Back',
#   'downtown',
#   ',',
#   'the',
#   'execs',
#   'squeezed',
#   'in',
#   'a',
#   'few',
#   'meetings',
#   'at',
#   'the',
#   'hotel',
#   'before',
#   '*-1',
#   'boarding',
#   'the',
#   'buses',
#   'again',
#   '.'],
#  ['This',
#   'time',
#   ',',
#   'it',
#   'was',
#   'for',
#   'dinner',
#   'and',
#   'dancing',
#   '--',
#   'a',
#   'block',
#   'away',
#   '.'],
#  ['Under',
#   'the',
#   'stars',
#   'and',
#   'moons',
#   'of',
#   'the',
#   'renovated',
#   'Indiana',
#   'Roof',
#   'ballroom',
#   ',',
#   'nine',
#   'of',
#   'the',
#   'hottest',
#   'chefs',
#   'in',
#   'town',
#   'fed',
#   'them',
#   'Indiana',
#   'duckling',
#   'mousseline',
#   ',',
#   'lobster',
#   'consomme',
#   ',',
#   'veal',
#   'mignon',
#   'and',
#   'chocolate',
#   'terrine',
#   'with',
#   'a',
#   'raspberry',
#   'sauce',
#   '.'],
#  ['*-2',
#   'Knowing',
#   'a',
#   'tasty',
#   '--',
#   'and',
#   'free',
#   '--',
#   'meal',
#   'when',
#   'they',
#   'eat',
#   'one',
#   '*T*-1',
#   ',',
#   'the',
#   'executives',
#   'gave',
#   'the',
#   'chefs',
#   'a',
#   'standing',
#   'ovation',
#   '.'],
#  ['More',
#   'than',
#   'a',
#   'few',
#   'CEOs',
#   'say',
#   '0',
#   'the',
#   'red-carpet',
#   'treatment',
#   'tempts',
#   'them',
#   'to',
#   'return',
#   'to',
#   'a',
#   'heartland',
#   'city',
#   'for',
#   'future',
#   'meetings',
#   '.'],
#  ['But',
#   'for',
#   'now',
#   ',',
#   'they',
#   "'re",
#   'looking',
#   'forward',
#   'to',
#   'their',
#   'winter',
#   'meeting',
#   '--',
#   'Boca',
#   'in',
#   'February',
#   '.'],
#  ['South',
#   'Korea',
#   'registered',
#   'a',
#   'trade',
#   'deficit',
#   'of',
#   '$',
#   '101',
#   'million',
#   '*U*',
#   'in',
#   'October',
#   ',',
#   '*',
#   'reflecting',
#   'the',
#   'country',
#   "'s",
#   'economic',
#   'sluggishness',
#   ',',
#   'according',
#   'to',
#   'government',
#   'figures',
#   'released',
#   '*',
#   'Wednesday',
#   '.'],
#  ['Preliminary',
#   'tallies',
#   'by',
#   'the',
#   'Trade',
#   'and',
#   'Industry',
#   'Ministry',
#   'showed',
#   'another',
#   'trade',
#   'deficit',
#   'in',
#   'October',
#   ',',
#   'the',
#   'fifth',
#   'monthly',
#   'setback',
#   'this',
#   'year',
#   ',',
#   '*',
#   'casting',
#   'a',
#   'cloud',
#   'on',
#   'South',
#   'Korea',
#   "'s",
#   'export-oriented',
#   'economy',
#   '.'],
#  ['Exports',
#   'in',
#   'October',
#   'stood',
#   'at',
#   '$',
#   '5.29',
#   'billion',
#   '*U*',
#   ',',
#   'a',
#   'mere',
#   '0.7',
#   '%',
#   'increase',
#   'from',
#   'a',
#   'year',
#   'earlier',
#   ',',
#   'while',
#   'imports',
#   'increased',
#   'sharply',
#   'to',
#   '$',
#   '5.39',
#   'billion',
#   '*U*',
#   ',',
#   'up',
#   '20',
#   '%',
#   'from',
#   'last',
#   'October',
#   '.'],
#  ['South',
#   'Korea',
#   "'s",
#   'economic',
#   'boom',
#   ',',
#   'which',
#   '*T*-12',
#   'began',
#   'in',
#   '1986',
#   ',',
#   'stopped',
#   'this',
#   'year',
#   'because',
#   'of',
#   'prolonged',
#   'labor',
#   'disputes',
#   ',',
#   'trade',
#   'conflicts',
#   'and',
#   'sluggish',
#   'exports',
#   '.'],
#  ['Government',
#   'officials',
#   'said',
#   '0',
#   'exports',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year',
#   'would',
#   'remain',
#   'under',
#   'a',
#   'government',
#   'target',
#   'of',
#   '$',
#   '68',
#   'billion',
#   '*U*',
#   '.'],
#  ['Despite',
#   'the',
#   'gloomy',
#   'forecast',
#   ',',
#   'South',
#   'Korea',
#   'has',
#   'recorded',
#   'a',
#   'trade',
#   'surplus',
#   'of',
#   '$',
#   '71',
#   'million',
#   '*U*',
#   'so',
#   'far',
#   'this',
#   'year',
#   '.'],
#  ['From',
#   'January',
#   'to',
#   'October',
#   ',',
#   'the',
#   'nation',
#   "'s",
#   'accumulated',
#   'exports',
#   'increased',
#   '4',
#   '%',
#   'from',
#   'the',
#   'same',
#   'period',
#   'last',
#   'year',
#   'to',
#   '$',
#   '50.45',
#   'billion',
#   '*U*',
#   '.'],
#  ['Imports',
#   'were',
#   'at',
#   '$',
#   '50.38',
#   'billion',
#   '*U*',
#   ',',
#   'up',
#   '19',
#   '%',
#   '.'],
#  ['Newsweek',
#   ',',
#   '*-1',
#   'trying',
#   '*-2',
#   'to',
#   'keep',
#   'pace',
#   'with',
#   'rival',
#   'Time',
#   'magazine',
#   ',',
#   'announced',
#   'new',
#   'advertising',
#   'rates',
#   'for',
#   '1990',
#   'and',
#   'said',
#   '0',
#   'it',
#   'will',
#   'introduce',
#   'a',
#   'new',
#   'incentive',
#   'plan',
#   'for',
#   'advertisers',
#   '.'],
#  ['The',
#   'new',
#   'ad',
#   'plan',
#   'from',
#   'Newsweek',
#   ',',
#   'a',
#   'unit',
#   'of',
#   'the',
#   'Washington',
#   'Post',
#   'Co.',
#   ',',
#   'is',
#   'the',
#   'second',
#   'incentive',
#   'plan',
#   '0',
#   'the',
#   'magazine',
#   'has',
#   'offered',
#   'advertisers',
#   '*T*-1',
#   'in',
#   'three',
#   'years',
#   '.'],
#  ['Plans',
#   'that',
#   '*T*-13',
#   'give',
#   'advertisers',
#   'discounts',
#   'for',
#   '*',
#   'maintaining',
#   'or',
#   'increasing',
#   'ad',
#   'spending',
#   'have',
#   'become',
#   'permanent',
#   'fixtures',
#   'at',
#   'the',
#   'news',
#   'weeklies',
#   'and',
#   'underscore',
#   'the',
#   'fierce',
#   'competition',
#   'between',
#   'Newsweek',
#   ',',
#   'Time',
#   'Warner',
#   'Inc.',
#   "'s",
#   'Time',
#   'magazine',
#   ',',
#   'and',
#   'Mortimer',
#   'B.',
#   'Zuckerman',
#   "'s",
#   'U.S.',
#   'News',
#   '&',
#   'World',
#   'Report',
#   '.'],
#  ['Alan',
#   'Spoon',
#   ',',
#   'recently',
#   'named',
#   '*',
#   'Newsweek',
#   'president',
#   ',',
#   'said',
#   '0',
#   'Newsweek',
#   "'s",
#   'ad',
#   'rates',
#   'would',
#   'increase',
#   '5',
#   '%',
#   'in',
#   'January',
#   '.'],
#  ['A',
#   'full',
#   ',',
#   'four-color',
#   'page',
#   'in',
#   'Newsweek',
#   'will',
#   'cost',
#   '$',
#   '100,980',
#   '*U*',
#   '.'],
#  ['In',
#   'mid-October',
#   ',',
#   'Time',
#   'magazine',
#   'lowered',
#   'its',
#   'guaranteed',
#   'circulation',
#   'rate',
#   'base',
#   'for',
#   '1990',
#   'while',
#   '*-1',
#   'not',
#   'increasing',
#   'ad',
#   'page',
#   'rates',
#   ';',
#   'with',
#   'a',
#   'lower',
#   'circulation',
#   'base',
#   ',',
#   'Time',
#   "'s",
#   'ad',
#   'rate',
#   '*ICH*-2',
#   'will',
#   'be',
#   'effectively',
#   '7.5',
#   '%',
#   'higher',
#   'per',
#   'subscriber',
#   ';',
#   'a',
#   'full',
#   'page',
#   'in',
#   'Time',
#   'costs',
#   'about',
#   '$',
#   '120,000',
#   '*U*',
#   '.'],
#  ['U.S.',
#   'News',
#   'has',
#   'yet',
#   '*-1',
#   'to',
#   'announce',
#   'its',
#   '1990',
#   'ad',
#   'rates',
#   '.'],
#  ['Newsweek',
#   'said',
#   '0',
#   'it',
#   'will',
#   'introduce',
#   'the',
#   'Circulation',
#   'Credit',
#   'Plan',
#   ',',
#   'which',
#   '*T*-1',
#   'awards',
#   'space',
#   'credits',
#   '*ICH*-2',
#   'to',
#   'advertisers',
#   'on',
#   '``',
#   'renewal',
#   'advertising',
#   '.',
#   "''"],
#  ['The',
#   'magazine',
#   'will',
#   'reward',
#   'with',
#   '``',
#   'page',
#   'bonuses',
#   "''",
#   'advertisers',
#   'who',
#   'in',
#   '1990',
#   '*T*-1',
#   'meet',
#   'or',
#   'exceed',
#   'their',
#   '1989',
#   'spending',
#   ',',
#   'as',
#   'long',
#   'as',
#   'they',
#   'spent',
#   '$',
#   '325,000',
#   '*U*',
#   'in',
#   '1989',
#   'and',
#   '$',
#   '340,000',
#   '*U*',
#   'in',
#   '1990',
#   '.'],
#  ['Mr.',
#   'Spoon',
#   'said',
#   '0',
#   'the',
#   'plan',
#   'is',
#   'not',
#   'an',
#   'attempt',
#   '*',
#   'to',
#   'shore',
#   'up',
#   'a',
#   'decline',
#   'in',
#   'ad',
#   'pages',
#   'in',
#   'the',
#   'first',
#   'nine',
#   'months',
#   'of',
#   '1989',
#   ';',
#   'Newsweek',
#   "'s",
#   'ad',
#   'pages',
#   'totaled',
#   '1,620',
#   ',',
#   'a',
#   'drop',
#   'of',
#   '3.2',
#   '%',
#   'from',
#   'last',
#   'year',
#   ',',
#   'according',
#   'to',
#   'Publishers',
#   'Information',
#   'Bureau',
#   '.'],
#  ['``',
#   'What',
#   '*T*-14',
#   'matters',
#   'is',
#   'what',
#   'advertisers',
#   'are',
#   'paying',
#   '*T*-15',
#   'per',
#   'page',
#   ',',
#   'and',
#   'in',
#   'that',
#   'department',
#   'we',
#   'are',
#   'doing',
#   'fine',
#   'this',
#   'fall',
#   ',',
#   "''",
#   'said',
#   '*T*-1',
#   'Mr.',
#   'Spoon',
#   '.'],
#  ['Both',
#   'Newsweek',
#   'and',
#   'U.S.',
#   'News',
#   'have',
#   'been',
#   'gaining',
#   'circulation',
#   'in',
#   'recent',
#   'years',
#   'without',
#   'heavy',
#   'use',
#   'of',
#   'electronic',
#   'giveaways',
#   'to',
#   'subscribers',
#   ',',
#   'such',
#   'as',
#   'telephones',
#   'or',
#   'watches',
#   '.'],
#  ['However',
#   ',',
#   'none',
#   'of',
#   'the',
#   'big',
#   'three',
#   'weeklies',
#   'recorded',
#   'circulation',
#   'gains',
#   'recently',
#   '.'],
#  ['According',
#   'to',
#   'Audit',
#   'Bureau',
#   'of',
#   'Circulations',
#   ',',
#   'Time',
#   ',',
#   'the',
#   'largest',
#   'newsweekly',
#   ',',
#   'had',
#   'average',
#   'circulation',
#   'of',
#   '4,393,237',
#   ',',
#   'a',
#   'decrease',
#   'of',
#   '7.3',
#   '%',
#   '.'],
#  ['Newsweek',
#   "'s",
#   'circulation',
#   'for',
#   'the',
#   'first',
#   'six',
#   'months',
#   'of',
#   '1989',
#   'was',
#   '3,288,453',
#   ',',
#   '*-1',
#   'flat',
#   'from',
#   'the',
#   'same',
#   'period',
#   'last',
#   'year',
#   '.'],
#  ['U.S.',
#   'News',
#   "'",
#   'circulation',
#   'in',
#   'the',
#   'same',
#   'time',
#   'was',
#   '2,303,328',
#   ',',
#   'down',
#   '2.6',
#   '%',
#   '.'],
#  ['New',
#   'England',
#   'Electric',
#   'System',
#   'bowed',
#   'out',
#   'of',
#   'the',
#   'bidding',
#   'for',
#   'Public',
#   'Service',
#   'Co.',
#   'of',
#   'New',
#   'Hampshire',
#   ',',
#   '*-1',
#   'saying',
#   'that',
#   'the',
#   'risks',
#   'were',
#   'too',
#   'high',
#   '*RNR*-4',
#   'and',
#   'the',
#   'potential',
#   'payoff',
#   'too',
#   'far',
#   'in',
#   'the',
#   'future',
#   '*RNR*-4',
#   '*',
#   'to',
#   'justify',
#   'a',
#   'higher',
#   'offer',
#   '.'],
#  ['The',
#   'move',
#   'leaves',
#   'United',
#   'Illuminating',
#   'Co.',
#   'and',
#   'Northeast',
#   'Utilities',
#   'as',
#   'the',
#   'remaining',
#   'outside',
#   'bidders',
#   'for',
#   'PS',
#   'of',
#   'New',
#   'Hampshire',
#   ',',
#   'which',
#   '*T*-1',
#   'also',
#   'has',
#   'proposed',
#   'an',
#   'internal',
#   'reorganization',
#   'plan',
#   'in',
#   'Chapter',
#   '11',
#   'bankruptcy',
#   'proceedings',
#   'under',
#   'which',
#   'it',
#   'would',
#   'remain',
#   'an',
#   'independent',
#   'company',
#   '*T*-2',
#   '.'],
#  ['New',
#   'England',
#   'Electric',
#   ',',
#   'based',
#   '*',
#   'in',
#   'Westborough',
#   ',',
#   'Mass.',
#   ',',
#   'had',
#   'offered',
#   '$',
#   '2',
#   'billion',
#   '*U*',
#   '*ICH*-1',
#   '*-4',
#   'to',
#   'acquire',
#   'PS',
#   'of',
#   'New',
#   'Hampshire',
#   ',',
#   'well',
#   'below',
#   'the',
#   '$',
#   '2.29',
#   'billion',
#   '*U*',
#   'value',
#   '0',
#   'United',
#   'Illuminating',
#   'places',
#   '*T*-2',
#   'on',
#   'its',
#   'bid',
#   'and',
#   'the',
#   '$',
#   '2.25',
#   'billion',
#   '*U*',
#   '0',
#   'Northeast',
#   'says',
#   '0',
#   'its',
#   'bid',
#   'is',
#   'worth',
#   '*T*-3',
#   '.'],
#  ['United',
#   'Illuminating',
#   'is',
#   'based',
#   '*-13',
#   'in',
#   'New',
#   'Haven',
#   ',',
#   'Conn.',
#   ',',
#   'and',
#   'Northeast',
#   'is',
#   'based',
#   '*-14',
#   'in',
#   'Hartford',
#   ',',
#   'Conn',
#   '.'],
#  ['PS',
#   'of',
#   'New',
#   'Hampshire',
#   ',',
#   'Manchester',
#   ',',
#   'N.H.',
#   ',',
#   'values',
#   'its',
#   'internal',
#   'reorganization',
#   'plan',
#   'at',
#   'about',
#   '$',
#   '2.2',
#   'billion',
#   '*U*',
#   '.'],
#  ['John',
#   'Rowe',
#   ',',
#   'president',
#   '*RNR*-1',
#   'and',
#   'chief',
#   'executive',
#   'officer',
#   '*RNR*-1',
#   'of',
#   'New',
#   'England',
#   'Electric',
#   ',',
#   'said',
#   '0',
#   'the',
#   'company',
#   "'s",
#   'return',
#   'on',
#   'equity',
#   'could',
#   'suffer',
#   'if',
#   'it',
#   'made',
#   'a',
#   'higher',
#   'bid',
#   'and',
#   'its',
#   'forecasts',
#   'related',
#   '*',
#   'to',
#   'PS',
#   'of',
#   'New',
#   'Hampshire',
#   '--',
#   'such',
#   'as',
#   'growth',
#   'in',
#   'electricity',
#   'demand',
#   'and',
#   'improved',
#   'operating',
#   'efficiencies',
#   '--',
#   'did',
#   "n't",
#   'come',
#   'true',
#   '.'],
#  ['``',
#   'When',
#   'we',
#   'evaluated',
#   '*-2',
#   'raising',
#   'our',
#   'bid',
#   '*T*-1',
#   ',',
#   'the',
#   'risks',
#   'seemed',
#   'substantial',
#   'and',
#   'persistent',
#   'over',
#   'the',
#   'next',
#   'five',
#   'years',
#   ',',
#   'and',
#   'the',
#   'rewards',
#   'seemed',
#   'a',
#   'long',
#   'way',
#   'out',
#   '.'],
#  ['That',
#   'got',
#   'hard',
#   '0',
#   '*',
#   'to',
#   'take',
#   '*T*-1',
#   ',',
#   "''",
#   'he',
#   'added',
#   '*T*-2',
#   '.'],
#  ['Mr.',
#   'Rowe',
#   'also',
#   'noted',
#   'that',
#   'political',
#   'concerns',
#   'also',
#   'worried',
#   'New',
#   'England',
#   'Electric',
#   '.'],
#  ['No',
#   'matter',
#   'who',
#   '*T*-16',
#   'owns',
#   'PS',
#   'of',
#   'New',
#   'Hampshire',
#   ',',
#   'after',
#   'it',
#   'emerges',
#   'from',
#   'bankruptcy',
#   'proceedings',
#   'its',
#   'rates',
#   'will',
#   'be',
#   'among',
#   'the',
#   'highest',
#   'in',
#   'the',
#   'nation',
#   ',',
#   'he',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['``', 'That', 'attracts', 'attention', '...'],
#  ['it',
#   'was',
#   'just',
#   'another',
#   'one',
#   'of',
#   'the',
#   'risk',
#   'factors',
#   "''",
#   'that',
#   '*T*-17',
#   'led',
#   'to',
#   'the',
#   'company',
#   "'s",
#   'decision',
#   '*',
#   'to',
#   'withdraw',
#   'from',
#   'the',
#   'bidding',
#   ',',
#   'he',
#   'added',
#   '0',
#   '*T*-1',
#   '.'],
#  ['Wilbur',
#   'Ross',
#   'Jr.',
#   'of',
#   'Rothschild',
#   'Inc.',
#   ',',
#   'the',
#   'financial',
#   'adviser',
#   'to',
#   'the',
#   'troubled',
#   'company',
#   "'s",
#   'equity',
#   'holders',
#   ',',
#   'said',
#   '0',
#   'the',
#   'withdrawal',
#   'of',
#   'New',
#   'England',
#   'Electric',
#   'might',
#   'speed',
#   'up',
#   'the',
#   'reorganization',
#   'process',
#   '.'],
#  ['The',
#   'fact',
#   'that',
#   'New',
#   'England',
#   'proposed',
#   'lower',
#   'rate',
#   'increases',
#   '--',
#   '4.8',
#   '%',
#   '*U*',
#   'over',
#   'seven',
#   'years',
#   'against',
#   'around',
#   '5.5',
#   '%',
#   'boosts',
#   'proposed',
#   '*',
#   'by',
#   'the',
#   'other',
#   'two',
#   'outside',
#   'bidders',
#   '--',
#   'complicated',
#   'negotiations',
#   'with',
#   'state',
#   'officials',
#   ',',
#   'Mr.',
#   'Ross',
#   'asserted',
#   '0',
#   '*T*-1',
#   '.'],
#  ['``',
#   'Now',
#   'the',
#   'field',
#   'is',
#   'less',
#   'cluttered',
#   ',',
#   "''",
#   'he',
#   'added',
#   '*T*-1',
#   '.'],
#  ['Separately',
#   ',',
#   'the',
#   'Federal',
#   'Energy',
#   'Regulatory',
#   'Commission',
#   'turned',
#   'down',
#   'for',
#   'now',
#   'a',
#   'request',
#   'by',
#   'Northeast',
#   'seeking',
#   'approval',
#   'of',
#   'its',
#   'possible',
#   'purchase',
#   'of',
#   'PS',
#   'of',
#   'New',
#   'Hampshire',
#   '.'],
#  ['Northeast',
#   'said',
#   '0',
#   'it',
#   'would',
#   'refile',
#   'its',
#   'request',
#   'and',
#   'still',
#   'hopes',
#   'for',
#   'an',
#   'expedited',
#   'review',
#   'by',
#   'the',
#   'FERC',
#   'so',
#   'that',
#   'it',
#   'could',
#   'complete',
#   'the',
#   'purchase',
#   'by',
#   'next',
#   'summer',
#   'if',
#   'its',
#   'bid',
#   'is',
#   'the',
#   'one',
#   'approved',
#   '*',
#   'by',
#   'the',
#   'bankruptcy',
#   'court',
#   '.'],
#  ['PS',
#   'of',
#   'New',
#   'Hampshire',
#   'shares',
#   'closed',
#   'yesterday',
#   'at',
#   '$',
#   '3.75',
#   '*U*',
#   ',',
#   'off',
#   '25',
#   'cents',
#   ',',
#   'in',
#   'New',
#   'York',
#   'Stock',
#   'Exchange',
#   'composite',
#   'trading',
#   '.'],
#  ['Norman',
#   'Ricken',
#   ',',
#   '52',
#   'years',
#   'old',
#   'and',
#   'former',
#   'president',
#   'and',
#   'chief',
#   'operating',
#   'officer',
#   'of',
#   'Toys',
#   '``',
#   'R',
#   "''",
#   'Us',
#   'Inc.',
#   ',',
#   'and',
#   'Frederick',
#   'Deane',
#   'Jr.',
#   ',',
#   '63',
#   ',',
#   'chairman',
#   'of',
#   'Signet',
#   'Banking',
#   'Corp.',
#   ',',
#   'were',
#   'elected',
#   '*-15',
#   'directors',
#   'of',
#   'this',
#   'consumer',
#   'electronics',
#   'and',
#   'appliances',
#   'retailing',
#   'chain',
#   '.'],
#  ['They',
#   'succeed',
#   'Daniel',
#   'M.',
#   'Rexinger',
#   ',',
#   'retired',
#   'Circuit',
#   'City',
#   'executive',
#   'vice',
#   'president',
#   ',',
#   'and',
#   'Robert',
#   'R.',
#   'Glauber',
#   ',',
#   'U.S.',
#   'Treasury',
#   'undersecretary',
#   ',',
#   'on',
#   'the',
#   '12-member',
#   'board',
#   '.'],
#  ['Commonwealth',
#   'Edison',
#   'Co.',
#   'was',
#   'ordered',
#   '*-1',
#   '*-2',
#   'to',
#   'refund',
#   'about',
#   '$',
#   '250',
#   'million',
#   '*U*',
#   'to',
#   'its',
#   'current',
#   'and',
#   'former',
#   'ratepayers',
#   'for',
#   'illegal',
#   'rates',
#   'collected',
#   '*',
#   'for',
#   'cost',
#   'overruns',
#   'on',
#   'a',
#   'nuclear',
#   'power',
#   'plant',
#   '.'],
#  ['The',
#   'refund',
#   'was',
#   'about',
#   '$',
#   '55',
#   'million',
#   '*U*',
#   'more',
#   'than',
#   '*',
#   'previously',
#   'ordered',
#   '*-1',
#   'by',
#   'the',
#   'Illinois',
#   'Commerce',
#   'Commission',
#   'and',
#   'trade',
#   'groups',
#   'said',
#   '0',
#   'it',
#   'may',
#   'be',
#   'the',
#   'largest',
#   'ever',
#   'required',
#   '*',
#   'of',
#   'a',
#   'state',
#   'or',
#   'local',
#   'utility',
#   '.'],
#  ['State',
#   'court',
#   'Judge',
#   'Richard',
#   'Curry',
#   'ordered',
#   'Edison',
#   '*-1',
#   'to',
#   'make',
#   'average',
#   'refunds',
#   'of',
#   'about',
#   '$',
#   '45',
#   'to',
#   '$',
#   '50',
#   '*U*',
#   'each',
#   'to',
#   'Edison',
#   'customers',
#   'who',
#   '*T*-18',
#   'have',
#   'received',
#   'electric',
#   'service',
#   'since',
#   'April',
#   '1986',
#   ',',
#   'including',
#   'about',
#   'two',
#   'million',
#   'customers',
#   'who',
#   '*T*-19',
#   'have',
#   'moved',
#   'during',
#   'that',
#   'period',
#   '.'],
#  ['Judge',
#   'Curry',
#   'ordered',
#   'the',
#   'refunds',
#   '*-1',
#   'to',
#   'begin',
#   'Feb.',
#   '1',
#   'and',
#   'said',
#   'that',
#   'he',
#   'would',
#   "n't",
#   'entertain',
#   'any',
#   'appeals',
#   'or',
#   'other',
#   'attempts',
#   '*',
#   'to',
#   'block',
#   'his',
#   'order',
#   'by',
#   'Commonwealth',
#   'Edison',
#   '.'],
#  ['``',
#   'The',
#   'refund',
#   'pool',
#   '...',
#   'may',
#   'not',
#   'be',
#   'held',
#   '*-1',
#   'hostage',
#   'through',
#   'another',
#   'round',
#   'of',
#   'appeals',
#   ',',
#   "''",
#   'Judge',
#   'Curry',
#   'said',
#   '*T*-2',
#   '.'],
#  ['Commonwealth',
#   'Edison',
#   'said',
#   '0',
#   'it',
#   'is',
#   'already',
#   'appealing',
#   'the',
#   'underlying',
#   'commission',
#   'order',
#   'and',
#   'is',
#   'considering',
#   '*-1',
#   'appealing',
#   'Judge',
#   'Curry',
#   "'s",
#   'order',
#   '.'],
#  ['The',
#   'exact',
#   'amount',
#   'of',
#   'the',
#   'refund',
#   'will',
#   'be',
#   'determined',
#   '*-16',
#   'next',
#   'year',
#   'based',
#   'on',
#   'actual',
#   'collections',
#   'made',
#   '*',
#   'until',
#   'Dec.',
#   '31',
#   'of',
#   'this',
#   'year',
#   '.'],
#  ['Commonwealth',
#   'Edison',
#   'said',
#   '0',
#   'the',
#   'ruling',
#   'could',
#   'force',
#   'it',
#   'to',
#   'slash',
#   'its',
#   '1989',
#   'earnings',
#   'by',
#   '$',
#   '1.55',
#   '*U*',
#   'a',
#   'share',
#   '.'],
#  ['For',
#   '1988',
#   ',',
#   'Commonwealth',
#   'Edison',
#   'reported',
#   'earnings',
#   'of',
#   '$',
#   '737.5',
#   'million',
#   '*U*',
#   ',',
#   'or',
#   '$',
#   '3.01',
#   '*U*',
#   'a',
#   'share',
#   '.'],
#  ['A',
#   'Commonwealth',
#   'Edison',
#   'spokesman',
#   'said',
#   'that',
#   '*',
#   'tracking',
#   'down',
#   'the',
#   'two',
#   'million',
#   'customers',
#   'whose',
#   'addresses',
#   '*T*-20',
#   'have',
#   'changed',
#   'during',
#   'the',
#   'past',
#   '3',
#   '1\\/2',
#   'years',
#   'would',
#   'be',
#   '``',
#   'an',
#   'administrative',
#   'nightmare',
#   '.',
#   "''"],
#  ['In',
#   'New',
#   'York',
#   'Stock',
#   'Exchange',
#   'composite',
#   'trading',
#   'yesterday',
#   ',',
#   'Commonwealth',
#   'Edison',
#   'closed',
#   'at',
#   '$',
#   '38.375',
#   '*U*',
#   ',',
#   'down',
#   '12.5',
#   'cents',
#   '.'],
#  ['The',
#   '$',
#   '2.5',
#   'billion',
#   '*U*',
#   'Byron',
#   '1',
#   'plant',
#   'near',
#   'Rockford',
#   ',',
#   'Ill.',
#   ',',
#   'was',
#   'completed',
#   '*-17',
#   'in',
#   '1985',
#   '.'],
#  ['In',
#   'a',
#   'disputed',
#   '1985',
#   'ruling',
#   ',',
#   'the',
#   'Commerce',
#   'Commission',
#   'said',
#   '0',
#   'Commonwealth',
#   'Edison',
#   'could',
#   'raise',
#   'its',
#   'electricity',
#   'rates',
#   'by',
#   '$',
#   '49',
#   'million',
#   '*U*',
#   '*-1',
#   'to',
#   'pay',
#   'for',
#   'the',
#   'plant',
#   '.'],
#  ['But',
#   'state',
#   'courts',
#   'upheld',
#   'a',
#   'challenge',
#   'by',
#   'consumer',
#   'groups',
#   'to',
#   'the',
#   'commission',
#   "'s",
#   'rate',
#   'increase',
#   'and',
#   'found',
#   'the',
#   'rates',
#   'illegal',
#   '.'],
#  ['The',
#   'Illinois',
#   'Supreme',
#   'Court',
#   'ordered',
#   'the',
#   'commission',
#   '*-1',
#   'to',
#   'audit',
#   'Commonwealth',
#   'Edison',
#   "'s",
#   'construction',
#   'expenses',
#   'and',
#   'refund',
#   'any',
#   'unreasonable',
#   'expenses',
#   '.'],
#  ['The',
#   'utility',
#   'has',
#   'been',
#   'collecting',
#   'for',
#   'the',
#   'plant',
#   "'s",
#   'construction',
#   'cost',
#   'from',
#   'its',
#   '3.1',
#   'million',
#   'customers',
#   'subject',
#   'to',
#   'a',
#   'refund',
#   'since',
#   '1986',
#   '.'],
#  ['In',
#   'August',
#   ',',
#   'the',
#   'commission',
#   'ruled',
#   'that',
#   'between',
#   '$',
#   '190',
#   'million',
#   'and',
#   '$',
#   '195',
#   'million',
#   '*U*',
#   'of',
#   'the',
#   'plant',
#   "'s",
#   'construction',
#   'cost',
#   'was',
#   'unreasonable',
#   'and',
#   'should',
#   'be',
#   'refunded',
#   '*-1',
#   ',',
#   'plus',
#   'interest',
#   '.'],
#  ['In',
#   'his',
#   'ruling',
#   ',',
#   'Judge',
#   'Curry',
#   'added',
#   'an',
#   'additional',
#   '$',
#   '55',
#   'million',
#   '*U*',
#   'to',
#   'the',
#   'commission',
#   "'s",
#   'calculations',
#   '.'],
#  ['Last',
#   'month',
#   ',',
#   'Judge',
#   'Curry',
#   'set',
#   'the',
#   'interest',
#   'rate',
#   'on',
#   'the',
#   'refund',
#   'at',
#   '9',
#   '%',
#   '.'],
#  ['Commonwealth',
#   'Edison',
#   'now',
#   'faces',
#   'an',
#   'additional',
#   'court-ordered',
#   'refund',
#   'on',
#   'its',
#   'summer\\/winter',
#   'rate',
#   'differential',
#   'collections',
#   'that',
#   'the',
#   'Illinois',
#   'Appellate',
#   'Court',
#   'has',
#   'estimated',
#   '*T*-1',
#   'at',
#   '$',
#   '140',
#   'million',
#   '*U*',
#   '.'],
#  ['And',
#   'consumer',
#   'groups',
#   'hope',
#   'that',
#   'Judge',
#   'Curry',
#   "'s",
#   'Byron',
#   '1',
#   'order',
#   'may',
#   'set',
#   'a',
#   'precedent',
#   'for',
#   'a',
#   'second',
#   'nuclear',
#   'rate',
#   'case',
#   'involving',
#   'Commonwealth',
#   'Edison',
#   "'s",
#   'Braidwood',
#   '2',
#   'plant',
#   '.'],
#  ['Commonwealth',
#   'Edison',
#   'is',
#   'seeking',
#   'about',
#   '$',
#   '245',
#   'million',
#   '*U*',
#   'in',
#   'rate',
#   'increases',
#   '0',
#   '*T*-1',
#   'to',
#   'pay',
#   'for',
#   'Braidwood',
#   '2',
#   '.'],
#  ['The',
#   'commission',
#   'is',
#   'expected',
#   '*-1',
#   'to',
#   'rule',
#   'on',
#   'the',
#   'Braidwood',
#   '2',
#   'case',
#   'by',
#   'year',
#   'end',
#   '.'],
#  ['Last',
#   'year',
#   'Commonwealth',
#   'Edison',
#   'had',
#   '*-1',
#   'to',
#   'refund',
#   '$',
#   '72.7',
#   'million',
#   '*U*',
#   'for',
#   'poor',
#   'performance',
#   'of',
#   'its',
#   'LaSalle',
#   'I',
#   'nuclear',
#   'plant',
#   '.'],
#  ['Japan',
#   "'s",
#   'domestic',
#   'sales',
#   'of',
#   'cars',
#   ',',
#   'trucks',
#   'and',
#   'buses',
#   'in',
#   'October',
#   'rose',
#   '18',
#   '%',
#   'from',
#   'a',
#   'year',
#   'earlier',
#   'to',
#   '500,004',
#   'units',
#   ',',
#   'a',
#   'record',
#   'for',
#   'the',
#   'month',
#   ',',
#   'the',
#   'Japan',
#   'Automobile',
#   'Dealers',
#   "'",
#   'Association',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['The',
#   'strong',
#   'growth',
#   'followed',
#   'year-to-year',
#   'increases',
#   'of',
#   '21',
#   '%',
#   'in',
#   'August',
#   'and',
#   '12',
#   '%',
#   'in',
#   'September',
#   '.'],
#  ['The',
#   'monthly',
#   'sales',
#   'have',
#   'been',
#   'setting',
#   'records',
#   'every',
#   'month',
#   'since',
#   'March',
#   '.'],
#  ['October',
#   'sales',
#   ',',
#   'compared',
#   '*',
#   'with',
#   'the',
#   'previous',
#   'month',
#   ',',
#   'inched',
#   'down',
#   '0.4',
#   '%',
#   '.'],
#  ['Sales',
#   'of',
#   'passenger',
#   'cars',
#   'grew',
#   '22',
#   '%',
#   'from',
#   'a',
#   'year',
#   'earlier',
#   'to',
#   '361,376',
#   'units',
#   '.'],
#  ['Sales',
#   'of',
#   'medium-sized',
#   'cars',
#   ',',
#   'which',
#   '*T*-21',
#   'benefited',
#   'from',
#   'price',
#   'reductions',
#   'arising',
#   'from',
#   'introduction',
#   'of',
#   'the',
#   'consumption',
#   'tax',
#   ',',
#   'more',
#   'than',
#   'doubled',
#   'to',
#   '30,841',
#   'units',
#   'from',
#   '13,056',
#   'in',
#   'October',
#   '1988',
#   '.'],
#  ['Texas',
#   'Instruments',
#   'Japan',
#   'Ltd.',
#   ',',
#   'a',
#   'unit',
#   'of',
#   'Texas',
#   'Instruments',
#   'Inc.',
#   ',',
#   'said',
#   '0',
#   'it',
#   'opened',
#   'a',
#   'plant',
#   '*ICH*-3',
#   'in',
#   'South',
#   'Korea',
#   '0',
#   '*T*-2',
#   'to',
#   'manufacture',
#   'control',
#   'devices',
#   '.'],
#  ['The',
#   'new',
#   'plant',
#   ',',
#   'located',
#   '*',
#   'in',
#   'Chinchon',
#   'about',
#   '60',
#   'miles',
#   'from',
#   'Seoul',
#   ',',
#   'will',
#   'help',
#   '*-2',
#   'meet',
#   'increasing',
#   'and',
#   'diversifying',
#   'demand',
#   'for',
#   'control',
#   'products',
#   'in',
#   'South',
#   'Korea',
#   ',',
#   'the',
#   'company',
#   'said',
#   '0',
#   '*T*-1',
#   '.'],
#  ['The',
#   'plant',
#   'will',
#   'produce',
#   'control',
#   'devices',
#   'used',
#   '*',
#   'in',
#   'motor',
#   'vehicles',
#   'and',
#   'household',
#   'appliances',
#   '.'],
#  ['The',
#   'survival',
#   'of',
#   'spinoff',
#   'Cray',
#   'Computer',
#   'Corp.',
#   'as',
#   'a',
#   'fledgling',
#   'in',
#   'the',
#   'supercomputer',
#   'business',
#   'appears',
#   '*-1',
#   'to',
#   'depend',
#   'heavily',
#   'on',
#   'the',
#   'creativity',
#   '--',
#   'and',
#   'longevity',
#   '--',
#   'of',
#   'its',
#   'chairman',
#   'and',
#   'chief',
#   'designer',
#   ',',
#   'Seymour',
#   'Cray',
#   '.'],
#  ['Not',
#   'only',
#   'is',
#   'development',
#   'of',
#   'the',
#   'new',
#   'company',
#   "'s",
#   'initial',
#   'machine',
#   'tied',
#   '*-1',
#   'directly',
#   'to',
#   'Mr.',
#   'Cray',
#   ',',
#   'so',
#   'is',
#   '*T*-2',
#   'its',
#   'balance',
#   'sheet',
#   '.'],
#  ['Documents',
#   'filed',
#   '*',
#   'with',
#   'the',
#   'Securities',
#   'and',
#   'Exchange',
#   'Commission',
#   'on',
#   'the',
#   'pending',
#   'spinoff',
#   'disclosed',
#   'that',
#   'Cray',
#   'Research',
#   'Inc.',
#   'will',
#   'withdraw',
#   'the',
#   'almost',
#   '$',
#   '100',
#   'million',
#   '*U*',
#   'in',
#   'financing',
#   '0',
#   'it',
#   'is',
#   'providing',
#   'the',
#   'new',
#   'firm',
#   '*T*-1',
#   'if',
#   'Mr.',
#   'Cray',
#   'leaves',
#   'or',
#   'if',
#   'the',
#   'product-design',
#   'project',
#   '0',
#   'he',
#   'heads',
#   '*T*-2',
#   'is',
#   'scrapped',
#   '*-18',
#   '.'],
#  ['The',
#   'documents',
#   'also',
#   'said',
#   'that',
#   'although',
#   'the',
#   '64-year-old',
#   'Mr.',
#   'Cray',
#   'has',
#   'been',
#   'working',
#   'on',
#   'the',
#   'project',
#   'for',
#   'more',
#   'than',
#   'six',
#   'years',
#   ',',
#   'the',
#   'Cray-3',
#   'machine',
#   'is',
#   'at',
#   'least',
#   'another',
#   'year',
#   'away',
#   'from',
#   'a',
#   'fully',
#   'operational',
#   'prototype',
#   '.'],
#  ['Moreover',
#   ',',
#   'there',
#   'have',
#   'been',
#   'no',
#   'orders',
#   'for',
#   'the',
#   'Cray-3',
#   'so',
#   'far',
#   ',',
#   'though',
#   'the',
#   'company',
#   'says',
#   '0',
#   'it',
#   'is',
#   'talking',
#   'with',
#   'several',
#   'prospects',
#   '.'],
#  ['While',
#   'many',
#   'of',
#   'the',
#   'risks',
#   'were',
#   'anticipated',
#   '*-19',
#   'when',
#   'Minneapolis-based',
#   'Cray',
#   'Research',
#   'first',
#   'announced',
#   'the',
#   'spinoff',
#   'in',
#   'May',
#   '*T*-1',
#   ',',
#   'the',
#   'strings',
#   '0',
#   'it',
#   'attached',
#   '*T*-2',
#   'to',
#   'the',
#   'financing',
#   'had',
#   "n't",
#   'been',
#   'made',
#   '*-3',
#   'public',
#   'until',
#   'yesterday',
#   '.'],
#  ['``',
#   'We',
#   'did',
#   "n't",
#   'have',
#   'much',
#   'of',
#   'a',
#   'choice',
#   ',',
#   "''",
#   'Cray',
#   'Computer',
#   "'s",
#   'chief',
#   'financial',
#   'officer',
#   ',',
#   'Gregory',
#   'Barnum',
#   ',',
#   'said',
#   '*T*-1',
#   'in',
#   'an',
#   'interview',
#   '.'],
#  ['``',
#   'The',
#   'theory',
#   'is',
#   'that',
#   'Seymour',
#   'is',
#   'the',
#   'chief',
#   'designer',
#   'of',
#   'the',
#   'Cray-3',
#   ',',
#   'and',
#   'without',
#   'him',
#   'it',
#   'could',
#   'not',
#   'be',
#   'completed',
#   '*-20',
#   '.'],
#  ['Cray',
#   'Research',
#   'did',
#   'not',
#   'want',
#   '*-1',
#   'to',
#   'fund',
#   'a',
#   'project',
#   'that',
#   '*T*-22',
#   'did',
#   'not',
#   'include',
#   'Seymour',
#   '.',
#   "''"],
#  ['The',
#   'documents',
#   'also',
#   'said',
#   'that',
#   'Cray',
#   'Computer',
#   'anticipates',
#   '*-1',
#   'needing',
#   'perhaps',
#   'another',
#   '$',
#   '120',
#   'million',
#   '*U*',
#   'in',
#   'financing',
#   'beginning',
#   'next',
#   'September',
#   '.'],
#  ['But',
#   'Mr.',
#   'Barnum',
#   'called',
#   'that',
#   '``',
#   'a',
#   'worst-case',
#   "''",
#   'scenario',
#   '.'],
#  ['The',
#   'filing',
#   'on',
#   'the',
#   'details',
#   'of',
#   'the',
#   'spinoff',
#   'caused',
#   'Cray',
#   'Research',
#   'stock',
#   'to',
#   'jump',
#   '$',
#   '2.875',
#   '*U*',
#   'yesterday',
#   '*-1',
#   'to',
#   'close',
#   'at',
#   '$',
#   '38',
#   '*U*',
#   'in',
#   'New',
#   'York',
#   'Stock',
#   'Exchange',
#   'composite',
#   'trading',
#   '.'],
#  ['Analysts',
#   'noted',
#   'yesterday',
#   'that',
#   'Cray',
#   'Research',
#   "'s",
#   'decision',
#   '*',
#   'to',
#   'link',
#   'its',
#   '$',
#   '98.3',
#   'million',
#   '*U*',
#   'promissory',
#   'note',
#   'to',
#   'Mr.',
#   'Cray',
#   "'s",
#   'presence',
#   'will',
#   'complicate',
#   'a',
#   'valuation',
# ...
#   "n't",
#   'be',
#   'threatened',
#   '*-2',
#   'against',
#   'attorneys',
#   'without',
#   'further',
#   'review',
#   'and',
#   'advance',
#   'notice',
#   '.'],
#  ['Mr.',
#   'Ross',
#   'said',
#   '0',
#   'IRS',
#   'officials',
#   'opposed',
#   'the',
#   'Justice',
#   'Department',
#   "'s",
#   'moderate',
#   'stance',
#   'on',
#   'the',
#   'matter',
#   '.'],
#  ['But',
#   'in',
#   'the',
#   'letters',
#   'sent',
#   '*',
#   'in',
#   'recent',
#   'days',
#   ',',
#   'Christopher',
#   'J.',
#   'Lezovich',
#   'of',
#   'the',
#   'IRS',
#   'computing',
#   'center',
#   'in',
#   'Detroit',
#   ',',
#   'told',
#   'attorneys',
#   'that',
#   '``',
#   '*',
#   'failing',
#   '*-1',
#   'to',
#   'voluntarily',
#   'submit',
#   'the',
#   'requested',
#   'information',
#   'could',
#   'result',
#   'in',
#   'summons',
#   'enforcement',
#   'action',
#   'being',
#   'initiated',
#   '*-2',
#   '.',
#   "''"],
#  ['In',
#   'some',
#   'cases',
#   ',',
#   'the',
#   'IRS',
#   'asked',
#   'for',
#   'information',
#   'dating',
#   'back',
#   'to',
#   'forms',
#   '0',
#   'it',
#   'received',
#   '*T*-1',
#   'in',
#   '1985',
#   '.'],
#  ['A',
#   'spokesman',
#   'for',
#   'the',
#   'IRS',
#   'confirmed',
#   'that',
#   '``',
#   'there',
#   'has',
#   'been',
#   'correspondence',
#   'mailed',
#   '*',
#   'about',
#   'incomplete',
#   '8300s',
#   ',',
#   "''",
#   'but',
#   'he',
#   'declined',
#   '*-1',
#   'to',
#   'say',
#   'why',
#   'the',
#   'letters',
#   'were',
#   'sent',
#   '*-2',
#   'to',
#   'lawyers',
#   'now',
#   '.'],
#  ['Individuals',
#   'familiar',
#   'with',
#   'the',
#   'Justice',
#   'Department',
#   "'s",
#   'policy',
#   'said',
#   'that',
#   'Justice',
#   'officials',
#   'had',
#   "n't",
#   'any',
#   'knowledge',
#   'of',
#   'the',
#   'IRS',
#   "'s",
#   'actions',
#   'in',
#   'the',
#   'last',
#   'week',
#   '.'],
#  ['Lawyers',
#   'worry',
#   'that',
#   'if',
#   'they',
#   'provide',
#   'information',
#   'about',
#   'clients',
#   ',',
#   'that',
#   'data',
#   'could',
#   'quickly',
#   'end',
#   'up',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'prosecutors',
#   '.'],
#  ['Prosecutors',
#   'need',
#   'court',
#   'permission',
#   '*-1',
#   'to',
#   'obtain',
#   'the',
#   'tax',
#   'returns',
#   'of',
#   'an',
#   'individual',
#   'or',
#   'a',
#   'business',
#   '.'],
#  ['But',
#   'they',
#   'have',
#   'obtained',
#   '8300',
#   'forms',
#   'without',
#   'court',
#   'permission',
#   'and',
#   'used',
#   'the',
#   'information',
#   '*-1',
#   'to',
#   'help',
#   'develop',
#   'criminal',
#   'cases',
#   '.'],
#  ['Some',
#   'criminal',
#   'lawyers',
#   'speculated',
#   'that',
#   'the',
#   'IRS',
#   'was',
#   'sending',
#   'the',
#   'letters',
#   '*-1',
#   'to',
#   'test',
#   'the',
#   'issue',
#   '.'],
#  ['In',
#   'a',
#   'number',
#   'of',
#   'recent',
#   'cases',
#   ',',
#   'federal',
#   'courts',
#   'have',
#   'refused',
#   '*-1',
#   'to',
#   'recognize',
#   'attorneys',
#   "'",
#   'assertions',
#   'that',
#   'information',
#   'relating',
#   'to',
#   'fees',
#   'from',
#   'clients',
#   'should',
#   'be',
#   'confidential',
#   '.'],
#  ['THE',
#   'WAR',
#   'OVER',
#   'FEDERAL',
#   'JUDICIAL',
#   'SALARIES',
#   'takes',
#   'a',
#   'victim',
#   '.'],
#  ['Often',
#   ',',
#   'judges',
#   'ease',
#   'into',
#   'more',
#   'lucrative',
#   'private',
#   'practice',
#   'with',
#   'little',
#   'fanfare',
#   ',',
#   'but',
#   'not',
#   'federal',
#   'Judge',
#   'Raul',
#   'A.',
#   'Ramirez',
#   'in',
#   'Sacramento',
#   ',',
#   'Calif',
#   '.'],
#  ['On',
#   'Tuesday',
#   ',',
#   'the',
#   'judge',
#   'called',
#   'a',
#   'news',
#   'conference',
#   '*-1',
#   'to',
#   'say',
#   '0',
#   'he',
#   'was',
#   'quitting',
#   '*',
#   'effective',
#   'Dec.',
#   '31',
#   '*-2',
#   'to',
#   'join',
#   'a',
#   'San',
#   'Francisco',
#   'law',
#   'firm',
#   '.'],
#  ['The',
#   'reason',
#   ':',
#   'the',
#   'refusal',
#   '*ICH*-1',
#   'of',
#   'Congress',
#   '*',
#   'to',
#   'give',
#   'federal',
#   'judges',
#   'a',
#   'raise',
#   '.'],
#  ['``',
#   'A',
#   'couple',
#   'of',
#   'my',
#   'law',
#   'clerks',
#   'were',
#   'going',
#   '*-1',
#   'to',
#   'pass',
#   'me',
#   'in',
#   'three',
#   'or',
#   'four',
#   'years',
#   ',',
#   'and',
#   'I',
#   'was',
#   'afraid',
#   '0',
#   'I',
#   'was',
#   'going',
#   '*-2',
#   'to',
#   'have',
#   '*-3',
#   'to',
#   'ask',
#   'them',
#   'for',
#   'a',
#   'loan',
#   ',',
#   "''",
#   'the',
#   'judge',
#   'quipped',
#   '*T*-4',
#   'in',
#   'an',
#   'interview',
#   '.'],
#  ['Federal',
#   'judges',
#   'make',
#   '$',
#   '89,500',
#   '*U*',
#   'annually',
#   ';',
#   'in',
#   'February',
#   ',',
#   'Congress',
#   'rejected',
#   'a',
#   'bill',
#   'that',
#   '*T*-1',
#   'would',
#   'have',
#   'increased',
#   'their',
#   'pay',
#   'by',
#   '50',
#   '%',
#   '.'],
#  ['Judge',
#   'Ramirez',
#   ',',
#   '44',
#   ',',
#   'said',
#   '0',
#   'it',
#   '*EXP*-3',
#   'is',
#   'unjust',
#   'for',
#   'judges',
#   'to',
#   'make',
#   'what',
#   'they',
#   'do',
#   '*?*',
#   '*T*-2',
#   '.'],
#  ['``',
#   'Judges',
#   'are',
#   'not',
#   'getting',
#   'what',
#   'they',
#   'deserve',
#   '*T*-1',
#   '.'],
#  ['You',
#   'look',
#   'around',
#   'at',
#   'professional',
#   'ballplayers',
#   'or',
#   'accountants',
#   '...',
#   'and',
#   'nobody',
#   'blinks',
#   'an',
#   'eye',
#   '.'],
#  ['When',
#   'you',
#   'become',
#   'a',
#   'federal',
#   'judge',
#   '*T*-1',
#   ',',
#   'all',
#   'of',
#   'a',
#   'sudden',
#   'you',
#   'are',
#   'relegated',
#   '*-2',
#   'to',
#   'a',
#   'paltry',
#   'sum',
#   '.',
#   "''"],
#  ['At',
#   'his',
#   'new',
#   'job',
#   ',',
#   'as',
#   'partner',
#   'in',
#   'charge',
#   'of',
#   'federal',
#   'litigation',
#   'in',
#   'the',
#   'Sacramento',
#   'office',
#   'of',
#   'Orrick',
#   ',',
#   'Herrington',
#   '&',
#   'Sutcliffe',
#   ',',
#   'he',
#   'will',
#   'make',
#   'out',
#   'much',
#   'better',
#   '.'],
#  ['The',
#   'judge',
#   'declined',
#   '*-1',
#   'to',
#   'discuss',
#   'his',
#   'salary',
#   'in',
#   'detail',
#   ',',
#   'but',
#   'said',
#   ':',
#   '``',
#   'I',
#   "'m",
#   'going',
#   '*-2',
#   'to',
#   'be',
#   'a',
#   'high-priced',
#   'lawyer',
#   '.',
#   "''"],
#  ['DOONESBURY',
#   "CREATOR'S",
#   'UNION',
#   'TROUBLES',
#   'are',
#   'no',
#   'laughing',
#   'matter',
#   '.'],
#  ['Cartoonist',
#   'Garry',
#   'Trudeau',
#   'is',
#   'suing',
#   'the',
#   'Writers',
#   'Guild',
#   'of',
#   'America',
#   'East',
#   'for',
#   '$',
#   '11',
#   'million',
#   '*U*',
#   ',',
#   '*-1',
#   'alleging',
#   '0',
#   'it',
#   'mounted',
#   'a',
#   '``',
#   'campaign',
#   '*',
#   'to',
#   'harass',
#   'and',
#   'punish',
#   "''",
#   'him',
#   'for',
#   '*',
#   'crossing',
#   'a',
#   'screenwriters',
#   "'",
#   'picket',
#   'line',
#   '.'],
#  ['The',
#   'dispute',
#   'involves',
#   'Darkhorse',
#   'Productions',
#   'Inc.',
#   ',',
#   'a',
#   'TV',
#   'production',
#   'company',
#   'in',
#   'which',
#   'Mr.',
#   'Trudeau',
#   'is',
#   'a',
#   'co-owner',
#   '*T*-1',
#   '.'],
#  ['Mr.',
#   'Trudeau',
#   ',',
#   'a',
#   'Writers',
#   'Guild',
#   'member',
#   ',',
#   'also',
#   'was',
#   'employed',
#   '*-1',
#   'as',
#   'a',
#   'writer',
#   'for',
#   'Darkhorse',
#   ',',
#   'which',
#   '*T*-134',
#   'was',
#   'covered',
#   '*-2',
#   'by',
#   'a',
#   'guild',
#   'collective-bargaining',
#   'agreement',
#   '.'],
#  ['The',
#   'guild',
#   'began',
#   'a',
#   'strike',
#   'against',
#   'the',
#   'TV',
#   'and',
#   'movie',
#   'industry',
#   'in',
#   'March',
#   '1988',
#   '.'],
#  ['In',
#   'his',
#   'lawsuit',
#   ',',
#   'Mr.',
#   'Trudeau',
#   'says',
#   '0',
#   'the',
#   'strike',
#   'illegally',
#   'included',
#   'Darkhorse',
#   ',',
#   'and',
#   'the',
#   'cartoonist',
#   'refused',
#   '*-1',
#   'to',
#   'honor',
#   'the',
#   'strike',
#   'against',
#   'the',
#   'company',
#   '.'],
#  ['A',
#   'spokesman',
#   'for',
#   'the',
#   'guild',
#   'said',
#   '0',
#   'the',
#   'union',
#   "'s",
#   'lawyers',
#   'are',
#   'reviewing',
#   'the',
#   'suit',
#   '.'],
#  ['He',
#   'said',
#   '0',
#   'disciplinary',
#   'proceedings',
#   'are',
#   'confidential',
#   'and',
#   'declined',
#   '*-1',
#   'to',
#   'comment',
#   'on',
#   'whether',
#   'any',
#   'are',
#   'being',
#   'held',
#   '*-2',
#   'against',
#   'Mr.',
#   'Trudeau',
#   '.'],
#  ['Mr.',
#   'Trudeau',
#   "'s",
#   'attorney',
#   ',',
#   'Norman',
#   'K.',
#   'Samnick',
#   ',',
#   'said',
#   '0',
#   'the',
#   'harassment',
#   'consists',
#   'mainly',
#   'of',
#   'the',
#   'guild',
#   "'s",
#   'year-long',
#   'threats',
#   'of',
#   'disciplinary',
#   'action',
#   '.'],
#  ['Mr.',
#   'Samnick',
#   'said',
#   '0',
#   'a',
#   'guild',
#   'disciplinary',
#   'hearing',
#   'is',
#   'scheduled',
#   '*-1',
#   'next',
#   'Monday',
#   'in',
#   'New',
#   'York',
#   '.'],
#  ['Mr.',
#   'Samnick',
#   ',',
#   'who',
#   '*T*-135',
#   'will',
#   'go',
#   'before',
#   'the',
#   'disciplinary',
#   'panel',
#   ',',
#   'said',
#   '0',
#   'the',
#   'proceedings',
#   'are',
#   'unfair',
#   'and',
#   'that',
#   'any',
#   'punishment',
#   'from',
#   'the',
#   'guild',
#   'would',
#   'be',
#   'unjustified',
#   '.'],
#  ['In',
#   'addition',
#   'to',
#   'the',
#   'damages',
#   ',',
#   'the',
#   'suit',
#   'seeks',
#   'a',
#   'court',
#   'order',
#   'preventing',
#   'the',
#   'guild',
#   'from',
#   '*-2',
#   'punishing',
#   '*RNR*-1',
#   'or',
#   'retaliating',
#   'against',
#   '*RNR*-1',
#   'Mr.',
#   'Trudeau',
#   '.'],
#  ['ABORTION', 'RULING', 'UPHELD', '*-1', ':'],
#  ['A',
#   'federal',
#   'appeals',
#   'court',
#   'upheld',
#   'a',
#   'lower',
#   'court',
#   'ruling',
#   'that',
#   'the',
#   'U.S.',
#   'can',
#   'bar',
#   'the',
#   'use',
#   'of',
#   'federal',
#   'funds',
#   'for',
#   'family-planning',
#   'programs',
#   'that',
#   '*T*-1',
#   'include',
#   'abortion-related',
#   'services',
#   '.'],
#  ['A',
#   'Department',
#   'of',
#   'Health',
#   'and',
#   'Human',
#   'Services',
#   'rule',
#   'adopted',
#   '*',
#   'in',
#   '1988',
#   'prohibits',
#   'the',
#   'use',
#   'of',
#   'so-called',
#   'Title',
#   'X',
#   'funds',
#   'for',
#   'programs',
#   'that',
#   '*T*-136',
#   'assist',
#   'a',
#   'woman',
#   'in',
#   '*-1',
#   'obtaining',
#   'an',
#   'abortion',
#   ',',
#   'such',
#   'as',
#   'abortion',
#   'counseling',
#   'and',
#   'referrals',
#   '.'],
#  ['The',
#   'rule',
#   'also',
#   'prohibits',
#   'funding',
#   'for',
#   'activities',
#   'that',
#   '``',
#   '*T*-137',
#   'encourage',
#   ',',
#   'promote',
#   'or',
#   'advocate',
#   'abortion',
#   '.',
#   "''"],
#  ['Title',
#   'X',
#   'funds',
#   'are',
#   'the',
#   'single',
#   'largest',
#   'source',
#   'of',
#   'federal',
#   'funding',
#   'for',
#   'family-planning',
#   'services',
#   ',',
#   'according',
#   'to',
#   'the',
#   'opinion',
#   'by',
#   'the',
#   'Second',
#   'U.S.',
#   'Circuit',
#   'Court',
#   'of',
#   'Appeals',
#   'in',
#   'New',
#   'York',
#   '.'],
#  ['The',
#   'panel',
#   'ruled',
#   'that',
#   'the',
#   'restrictions',
#   'do',
#   "n't",
#   'violate',
#   'the',
#   'freedom',
#   'of',
#   'speech',
#   'of',
#   'health',
#   'care',
#   'providers',
#   'and',
#   'that',
#   'the',
#   'limits',
#   'on',
#   'counseling',
#   'services',
#   'do',
#   "n't",
#   'violate',
#   'the',
#   'rights',
#   'of',
#   'pregnant',
#   'women',
#   '.'],
#  ['INQUIRY',
#   'CLEARS',
#   'TEXAS',
#   'JUDGE',
#   'of',
#   'bias',
#   'in',
#   'comments',
#   'on',
#   'homosexual',
#   'murder',
#   'victims',
#   '.'],
#  ['Dallas',
#   'District',
#   'Judge',
#   'Jack',
#   'Hampton',
#   'had',
#   'sparked',
#   'calls',
#   'for',
#   'a',
#   'judicial',
#   'inquiry',
#   'with',
#   'his',
#   'remarks',
#   'to',
#   'the',
#   'press',
#   'last',
#   'December',
#   ',',
#   'two',
#   'weeks',
#   'after',
#   '*-1',
#   'sentencing',
#   'an',
#   '18-year-old',
#   'defendant',
#   'to',
#   '30',
#   'years',
#   'in',
#   'state',
#   'prison',
#   'for',
#   '*-2',
#   'killing',
#   'two',
#   'homosexual',
#   'men',
#   'in',
#   'a',
#   'city',
#   'park',
#   '.'],
#  ['The',
#   'judge',
#   'was',
#   'quoted',
#   '*-1',
#   'as',
#   '*-4',
#   'referring',
#   'to',
#   'the',
#   'victims',
#   'as',
#   '``',
#   'queers',
#   "''",
#   'and',
#   '*-4',
#   'saying',
#   '0',
#   'they',
#   'would',
#   "n't",
#   'have',
#   'been',
#   'killed',
#   '*-2',
#   '``',
#   'if',
#   'they',
#   'had',
#   "n't",
#   'been',
#   'cruising',
#   'the',
#   'streets',
#   '*-3',
#   'picking',
#   'up',
#   'teenage',
#   'boys',
#   '.',
#   "''"],
#  ['But',
#   'Robert',
#   'R.',
#   'Murray',
#   ',',
#   'a',
#   'special',
#   'master',
#   'appointed',
#   '*',
#   'by',
#   'the',
#   'Texas',
#   'Supreme',
#   'Court',
#   ',',
#   'said',
#   '0',
#   'Judge',
#   'Hampton',
#   'did',
#   "n't",
#   'breach',
#   'any',
#   'judicial',
#   'standards',
#   'of',
#   'fairness',
#   ',',
#   'although',
#   'he',
#   'did',
#   'violate',
#   'the',
#   'state',
#   "'s",
#   'judicial',
#   'code',
#   'by',
#   '*-1',
#   'commenting',
#   'publicly',
#   'on',
#   'a',
#   'pending',
#   'case',
#   '.'],
#  ['*-1',
#   'Observing',
#   'that',
#   'the',
#   'judge',
#   '``',
#   'has',
#   'never',
#   'exhibited',
#   'any',
#   'bias',
#   'or',
#   'prejudice',
#   ',',
#   "''",
#   'Mr.',
#   'Murray',
#   'concluded',
#   'that',
#   'he',
#   '``',
#   'would',
#   'be',
#   'impartial',
#   'in',
#   'any',
#   'case',
#   'involving',
#   'a',
#   'homosexual',
#   'or',
#   'prostitute',
#   "''",
#   'as',
#   'a',
#   'victim',
#   '.'],
#  ['Mr.',
#   'Murray',
#   'also',
#   'said',
#   '0',
#   'Judge',
#   'Hampton',
#   "'s",
#   'comments',
#   'did',
#   "n't",
#   'discredit',
#   'the',
#   'judiciary',
#   'or',
#   'the',
#   'administration',
#   'of',
#   'justice',
#   '.'],
#  ['The',
#   'report',
#   'is',
#   'subject',
#   'to',
#   'review',
#   'by',
#   'the',
#   'State',
#   'Commission',
#   'on',
#   'Judicial',
#   'Conduct',
#   ',',
#   'which',
#   '*T*-138',
#   'is',
#   'empowered',
#   '*-1',
#   'to',
#   'impose',
#   'sanctions',
#   '.'],
#  ['GAF', 'TRIAL', 'goes', 'to', 'round', 'three', '.'],
#  ['Attorneys',
#   'in',
#   'the',
#   'third',
#   'stock-manipulation',
#   'trial',
#   'of',
#   'GAF',
#   'Corp.',
#   'began',
#   'opening',
#   'arguments',
#   'yesterday',
#   'in',
#   'the',
#   'Manhattan',
#   'courtroom',
#   'of',
#   'U.S.',
#   'District',
#   'Judge',
#   'Mary',
#   'Johnson',
#   'Lowe',
#   '.'],
#  ['In',
#   'an',
#   'eight-count',
#   'indictment',
#   ',',
#   'the',
#   'government',
#   'has',
#   'charged',
#   'GAF',
#   ',',
#   'a',
#   'Wayne',
#   ',',
#   'N.J.',
#   ',',
#   'specialty',
#   'chemical',
#   'maker',
#   ',',
#   'and',
#   'its',
#   'Vice',
#   'Chairman',
#   'James',
#   'T.',
#   'Sherwin',
#   'with',
#   '*-2',
#   'attempting',
#   '*-1',
#   'to',
#   'manipulate',
#   'the',
#   'common',
#   'stock',
#   'of',
#   'Union',
#   'Carbide',
#   'Corp.',
#   'in',
#   'advance',
#   'of',
#   'GAF',
#   "'s",
#   'planned',
#   'sale',
#   'of',
#   'a',
#   'large',
#   'block',
#   'of',
#   'the',
#   'stock',
#   'in',
#   'November',
#   '1986',
#   '.'],
#  ['The',
#   'first',
#   'two',
#   'GAF',
#   'trials',
#   'ended',
#   'in',
#   'mistrials',
#   'earlier',
#   'this',
#   'year',
#   '.'],
#  ['This',
#   'trial',
#   'is',
#   'expected',
#   '*-1',
#   'to',
#   'last',
#   'five',
#   'weeks',
#   '.'],
#  ['*', 'SWITCHING', 'TO', 'THE', 'DEFENSE', ':'],
#  ['A',
#   'former',
#   'member',
#   'of',
#   'the',
#   'prosecution',
#   'team',
#   'in',
#   'the',
#   'Iran\\/Contra',
#   'affair',
#   'joined',
#   'the',
#   'Chicago',
#   'firm',
#   'of',
#   'Mayer',
#   ',',
#   'Brown',
#   '&',
#   'Platt',
#   '.'],
#  ['Michael',
#   'R.',
#   'Bromwich',
#   ',',
#   'a',
#   'member',
#   'since',
#   'January',
#   '1987',
#   'of',
#   'the',
#   'three-lawyer',
#   'trial',
#   'team',
#   'in',
#   'the',
#   'prosecution',
#   'of',
#   'Oliver',
#   'North',
#   ',',
#   'became',
#   'a',
#   'partner',
#   'in',
#   'the',
#   'Washington',
#   ',',
#   'D.C.',
#   ',',
#   'office',
#   'of',
#   'the',
#   '520-lawyer',
#   'firm',
#   '.'],
#  ['He',
#   'will',
#   'specialize',
#   'in',
#   'white-collar',
#   'criminal',
#   'defense',
#   'work',
#   '.'],
#  ['Mr.',
#   'Bromwich',
#   ',',
#   '35',
#   ',',
#   'also',
#   'has',
#   'served',
#   'as',
#   'deputy',
#   'chief',
#   '*RNR*-1',
#   'and',
#   'chief',
#   '*RNR*-1',
#   'of',
#   'the',
#   'narcotics',
#   'unit',
#   'for',
#   'the',
#   'U.S.',
#   'attorney',
#   "'s",
#   'office',
#   'for',
#   'the',
#   'Southern',
#   'District',
#   'of',
#   'New',
#   'York',
#   ',',
#   'based',
#   '*',
#   'in',
#   'Manhattan',
#   '.'],
#  ['Cooper',
#   'Tire',
#   '&',
#   'Rubber',
#   'Co.',
#   'said',
#   '0',
#   'it',
#   'has',
#   'reached',
#   'an',
#   'agreement',
#   '*ICH*-1',
#   'in',
#   'principle',
#   '*',
#   'to',
#   'buy',
#   'buildings',
#   'and',
#   'related',
#   'property',
#   'in',
#   'Albany',
#   ',',
#   'Ga.',
#   ',',
#   'from',
#   'Bridgestone\\/Firestone',
#   'Inc',
#   '.'],
#  ['Terms', 'were', "n't", 'disclosed', '*-1', '.'],
#  ['The',
#   'tire',
#   'maker',
#   'said',
#   '0',
#   'the',
#   'buildings',
#   'consist',
#   'of',
#   '1.8',
#   'million',
#   'square',
#   'feet',
#   'of',
#   'office',
#   ',',
#   'manufacturing',
#   'and',
#   'warehousing',
#   'space',
#   'on',
#   '353',
#   'acres',
#   'of',
#   'land',
#   '.'],
#  ['Fujitsu',
#   'Ltd.',
#   "'s",
#   'top',
#   'executive',
#   'took',
#   'the',
#   'unusual',
#   'step',
#   'of',
#   '*',
#   'publicly',
#   'apologizing',
#   'for',
#   'his',
#   'company',
#   "'s",
#   'making',
#   'bids',
#   'of',
#   'just',
#   'one',
#   'yen',
#   'for',
#   'several',
#   'local',
#   'government',
#   'projects',
#   ',',
#   'while',
#   'computer',
#   'rival',
#   'NEC',
#   'Corp.',
#   'made',
#   'a',
#   'written',
#   'apology',
#   'for',
#   '*',
#   'indulging',
#   'in',
#   'the',
#   'same',
#   'practice',
#   '.'],
#  ...]

# %%
y #Output Variable
# Out:
# [['NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'PRON',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'ADJ',
#   '.',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'X',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   '.',
#   'DET',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET', 'VERB', 'DET', 'NOUN', 'ADP', 'PRON', 'NOUN', 'ADV', '.', '.'],
#  ['DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'CONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'],
#  ['ADP',
#   'NUM',
#   'PRT',
#   'NUM',
#   '.',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['ADP',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NUM',
#   'X',
#   'VERB',
#   'VERB',
#   '.',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NUM',
#   'ADP',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'NUM',
#   'ADP',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'X',
#   'VERB',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'PRON',
#   'PRON',
#   'X',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'PRON',
#   'X',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NUM',
#   '.',
#   'ADV',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   '.'],
#  ['ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'X',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['.',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   '.'],
#  ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'PRON', 'NOUN', 'NOUN', 'NOUN', '.'],
#  ['NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'PRT',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['ADV',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRT',
#   '.',
#   'ADP',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRT',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['ADV',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'PRON',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'DET',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'X',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['NOUN',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADV',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADV',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   '.',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'PRT',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADV', 'DET', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'X',
#   'PRT',
#   'VERB',
#   'PRT',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'X',
#   '.'],
#  ['ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN', 'CONJ', 'NOUN', 'VERB', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRON',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'X',
#   '.'],
#  ['ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'NUM',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['X',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'X',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   '.'],
#  ['ADV',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['X',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'CONJ',
#   'ADJ',
#   '.',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'NUM',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADP',
#   'ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'PRT',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRT',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'ADP',
#   'NUM',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'X',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'CONJ',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'NUM',
#   'X',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'X',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'X',
#   'VERB',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PRT',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NUM',
#   'X',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.',
#   'NUM',
#   'X',
#   'ADP',
#   'NUM',
#   'CONJ',
#   '.',
#   'NUM',
#   'X',
#   'ADP',
#   'NUM',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['.',
#   'PRON',
#   'X',
#   'VERB',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['VERB',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADV',
#   '.',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'VERB',
#   'NUM',
#   '.',
#   'X',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NUM',
#   '.',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'X',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'X',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'X',
#   'CONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['.',
#   'ADV',
#   'PRON',
#   'VERB',
#   'X',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   '.'],
#  ['DET',
#   'VERB',
#   'ADV',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'X',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['.', 'DET', 'VERB', 'NOUN', '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'X',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   '.'],
#  ['ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   '.',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'PRT',
#   'PRON',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADJ',
#   'ADP',
#   'X',
#   'ADV',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADP',
#   '.',
#   'NUM',
#   'PRT',
#   '.',
#   'NUM',
#   'X',
#   'DET',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NUM',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'CONJ',
#   '.',
#   'NUM',
#   'X',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'X',
#   'VERB',
#   'PRT',
#   'DET',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'X',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   '.',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NUM',
#   '.'],
#  ['ADP',
#   'DET',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'CONJ',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'PRON',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'PRT',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.'],
#  ['CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PRT',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PRT',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'VERB',
#   'PRT',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADV',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'X',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADV',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   '.',
#   'DET',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'PRT',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'VERB',
#   'ADV',
#   'DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ', 'NOUN', 'NOUN', 'VERB', 'ADP', '.', 'DET', 'ADJ', '.', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   'NUM',
#   'X',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   '.'],
#  ['.',
#   'PRON',
#   'ADV',
#   'VERB',
#   'X',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADV',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'X',
#   '.',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'X',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'NUM',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'DET',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'CONJ',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   '.'],
#  ['ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN', 'NOUN', 'VERB', 'VERB', 'X', 'PRT', 'VERB', 'ADP', 'NOUN', '.'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADP',
#   '.',
#   'NUM',
#   'X',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'VERB',
#   'PRT',
#   'DET',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'DET',
#   'ADP',
#   'NUM',
#   'ADV',
#   'ADP',
#   'DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'X',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['X',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   'NUM',
#   'X',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['DET', 'VERB', 'ADP', 'NOUN', 'NOUN', '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'ADV',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   '.',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
# ...
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   '.'],
#  ['X',
#   'VERB',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'X',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'ADP',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'X',
#   'CONJ',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADP',
#   '.',
#   'X',
#   'VERB',
#   'X',
#   'PRT',
#   'ADV',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRT',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'X',
#   'ADP',
#   'NUM',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'DET',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', '.'],
#  ['ADV',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'NUM',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NUM',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'NUM',
#   'X',
#   'ADV',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'VERB',
#   'X',
#   'PRON',
#   'X',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'PRON',
#   'VERB',
#   'X',
#   'X',
#   '.'],
#  ['.', 'NOUN', 'VERB', 'ADV', 'VERB', 'PRON', 'PRON', 'VERB', 'X', '.'],
#  ['PRON',
#   'VERB',
#   'PRT',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'X',
#   '.',
#   'DET',
#   'ADP',
#   'DET',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADV',
#   'ADV',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NUM',
#   'NUM',
#   'X',
#   '.',
#   'X',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'DET',
#   '.',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.',
#   'PRON',
#   'ADP',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'],
#  ['ADP',
#   'PRON',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'X',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'X',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'X',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN', 'NOUN', 'VERB', 'X', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   '.',
#   'X',
#   'VERB',
#   '.',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   '.',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADP',
#   'X',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'X',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   'X',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'VERB',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['X',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'X',
#   'VERB',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN', 'NOUN', 'VERB', 'PRT', 'NOUN', 'NUM', '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'X',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'VERB', 'X', 'PRT', 'VERB', 'NUM', 'NOUN', '.'],
#  ['X', 'VERB', 'PRT', 'DET', 'NOUN', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'VERB', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'CONJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN', 'VERB', 'ADV', 'VERB', 'X', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ...]

# %% [markdown]
# ## Checking Both xi and yi are in same length or not

# %%
c=0
for i in range(len(x)):
    if len(x[i])==len(y[i]):
        pass
    else:
        c+=1
c
# Out:
# 0

# %% [markdown]
# ## Finding vocabulary Size

# %%
voc = []
for q in x:
    for word in q:
        if word.lower() not in voc:
            voc.append(word.lower())

# %%
len(voc) #No of unique words in your courpus
# Out:
# 53232

# %% [markdown]
# ## Preprocessing and Tokenization

# %%
tk_x = Tokenizer(oov_token='UNK')
tk_x.fit_on_texts(x)

# %%
len(tk_x.word_index)
# Out:
# 53233

# %%
tk_y = Tokenizer(oov_token='OOV')
tk_y.fit_on_texts(y)

# %%
len(tk_y.word_index)
# Out:
# 13

# %%
tk_y.index_word
# Out:
# {1: 'OOV',
#  2: 'noun',
#  3: 'verb',
#  4: '.',
#  5: 'adp',
#  6: 'det',
#  7: 'adj',
#  8: 'adv',
#  9: 'pron',
#  10: 'conj',
#  11: 'prt',
#  12: 'num',
#  13: 'x'}

# %%
x_d = tk_x.texts_to_sequences(x)
y_d = tk_y.texts_to_sequences(y)

# %%
len(x_d)
# Out:
# 61254

# %% [markdown]
# ## Padding

# %%
final_x_d = pad_sequences(x_d,padding='post')
final_y_d = pad_sequences(y_d,padding='post')

# %%
final_x_d.shape
# Out:
# (61254, 271)

# %%
final_y_d.shape
# Out:
# (61254, 271)

# %%
final_y_d
# Out:
# array([[2, 2, 4, ..., 0, 0, 0],
#        [2, 2, 3, ..., 0, 0, 0],
#        [2, 2, 4, ..., 0, 0, 0],
#        ...,
#        [6, 2, 5, ..., 0, 0, 0],
#        [9, 3, 6, ..., 0, 0, 0],
#        [5, 6, 9, ..., 0, 0, 0]])

# %%
final_y = to_categorical(final_y_d)

# %%
final_y.shape
# Out:
# (61254, 271, 14)

# %% [markdown]
# ## Model Building

# %%
model = Sequential()
model.add(InputLayer(input_shape=(271,)))
model.add(Embedding(53233+1,5))
model.add(Bidirectional(SimpleRNN(units=50,return_sequences=True)))
model.add(TimeDistributed(Dense(units=14,activation='softmax')))
# Out:
# C:\Users\CHARISHMA\.conda\envs\charishma\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 271, 5)         │       266,170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 271, 100)       │         5,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 271, 14)        │         1,414 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 273,184 (1.04 MB)
#  Trainable params: 273,184 (1.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(final_x_d,final_y,epochs=5,batch_size=120,validation_split=0.2)
# Out:
# Epoch 1/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 272s 633ms/step - accuracy: 0.9134 - loss: 0.3610 - val_accuracy: 0.9830 - val_loss: 0.0595
# Epoch 2/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 237s 579ms/step - accuracy: 0.9814 - loss: 0.0654 - val_accuracy: 0.9924 - val_loss: 0.0269
# Epoch 3/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 238s 582ms/step - accuracy: 0.9913 - loss: 0.0324 - val_accuracy: 0.9957 - val_loss: 0.0156
# Epoch 4/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 237s 580ms/step - accuracy: 0.9951 - loss: 0.0181 - val_accuracy: 0.9967 - val_loss: 0.0117
# Epoch 5/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 238s 581ms/step - accuracy: 0.9966 - loss: 0.0125 - val_accuracy: 0.9972 - val_loss: 0.0097

# %%
te = ["dhoni loves playing cricket and he is from ranchi"]

# %%
tk_x.texts_to_sequences(te)
# Out:
# [[1, 5515, 1117, 20352, 6, 14, 11, 30, 1]]

# %%
tk_x.sequences_to_texts(tk_x.texts_to_sequences(te))
# Out:
# ['UNK loves playing cricket and he is from UNK']

# %%
test = pad_sequences(tk_x.texts_to_sequences(te),maxlen=271,padding='post')

# %%
np.argmax(model.predict(test)[0],axis=1)[np.argmax(model.predict(test)[0],axis=1)!=0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# array([ 2,  3,  3,  2, 10,  9,  3,  5,  7], dtype=int64)

# %%
tk_y.sequences_to_texts([[7, 2, 9, 3]])
# Out:
# ['adj noun pron verb']

# %%
pickle.dump(tk_x,open(r"D:\streamlit\Deep Learning\POS Tag\tk_x.pkl",'wb'))

# %%
pickle.dump(tk_y,open(r"D:\streamlit\Deep Learning\POS Tag\tk_y.pkl",'wb'))

# %%
pickle.dump(model,open(r"D:\streamlit\Deep Learning\POS Tag\model.pkl",'wb'))

# %%
model.save(r"D:\streamlit\Deep Learning\POS Tag\model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
